# %%
import matplotlib.pyplot as plt
import seaborn as sns
from rdkit import Chem
import numpy as np
import pandas as pd
import copy
import argparse
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.nn import Linear
from torch.nn import BatchNorm1d
import torch.optim as optim
from torch.utils.data import Dataset
from torch_geometric.nn import GCNConv, GATConv
from torch_geometric.nn import global_add_pool
from torch_geometric.data import Data
from torch_geometric.loader import DataLoader
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import confusion_matrix, f1_score
import warnings
warnings.filterwarnings(action='ignore')

# %%
paser = argparse.ArgumentParser()
args = paser.parse_args("")
args.seed = 2023
    
np.random.seed(args.seed)
torch.manual_seed(args.seed)
device = torch.device('cuda:1' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda', index=1)

# %%
def one_of_k_encoding_unk(x, allowable_set):
    if x not in allowable_set:
        x = allowable_set[-1]
    return list(map(lambda s: x == s, allowable_set))

def atom_features(atom):
    results = np.array(one_of_k_encoding_unk(atom.GetSymbol(), ['B', 'C', 'Cl', 'N', 'O', 'P', 'S']) + 
                       one_of_k_encoding_unk(atom.GetDegree(), [1, 2, 3, 4]) + 
                       one_of_k_encoding_unk(atom.GetImplicitValence(), [0, 1, 2, 3]) + 
                       [atom.GetFormalCharge(), atom.GetNumRadicalElectrons()] + 
                       one_of_k_encoding_unk(atom.GetHybridization(), [Chem.rdchem.HybridizationType.SP, 
                                                                       Chem.rdchem.HybridizationType.SP2, 
                                                                       Chem.rdchem.HybridizationType.SP3, 
                                                                       Chem.rdchem.HybridizationType.SP3D, 
                                                                       Chem.rdchem.HybridizationType.SP3D2]) + 
                       [atom.GetIsAromatic()]+
                       one_of_k_encoding_unk(atom.GetTotalNumHs(), [0, 1, 2, 3]))
    return results
 

def get_bond_pair(mol):
    bonds = mol.GetBonds()
    res = [[],[]]
    for bond in bonds:
        res[0] += [bond.GetBeginAtomIdx(), bond.GetEndAtomIdx()]
        res[1] += [bond.GetEndAtomIdx(), bond.GetBeginAtomIdx()]
    return res
 
def mol2vec(mol):
    atoms = mol.GetAtoms()
    node_feat= [atom_features(atom) for atom in atoms]
    edge_index = get_bond_pair(mol)
    data = Data(x=torch.tensor(node_feat, dtype=torch.float),
                edge_index=torch.tensor(edge_index, dtype=torch.long))
    return data

# %%
def make_mol(df):
    mols = {}
    for i in range(df.shape[0]):
        mols[Chem.MolFromSmiles(df['SMILES'].iloc[i])] = df['Class'].iloc[i]
    return mols

# %%
def make_vec(mols):
    X = [mol2vec(m) for m in mols.keys()]
    for i, data in enumerate(X):
        y = list(mols.values())[i]
        data.y = torch.tensor([y], dtype=torch.long)
    return X

# %%
df = pd.read_csv('./LMSD_dataset.csv')
classes = {c:i for i,c in enumerate(df['Category'].unique())}
df['Class'] = 0
for i in range(df.shape[0]):
    df.loc[i, 'Class'] = classes[df['Category'].iloc[i]]
df
# Out:
#                                                   SMILES     Category  Class
# 0      C=CCCCCC(C)CCCCCC#CCCC(OC)C(=O)OC(=O)C(CCC#CCC...  Fatty Acyls      0
# 1                 CCCCCCC[C@H](O)CC(=O)N[C@@H](CO)C(=O)O  Fatty Acyls      0
# 2      CCCCCCCCCCCCCCCC(=O)OC(CCCCCCCCCCCCCC)CC(=O)N[...  Fatty Acyls      0
# 3      CC/C=C\C/C=C\C/C=C\CCCCCCCC(=O)N[C@@H](CCC(N)=...  Fatty Acyls      0
# 4      CC(C)CCCCCCCCCCCCCC(=O)OC(CCCCCCCCCCCC(C)C)CC(...  Fatty Acyls      0
# ...                                                  ...          ...    ...
# 47334     CCCCCCCCCCC[C@H](CC1=CC(=O)C=C(OC)C1=O)OC(C)=O  Polyketides      7
# 47335                  CCCCCCCCCCCC1=C(O)C(=O)C=C(O)C1=O  Polyketides      7
# 47336                 CCCCCCCCCCCC1=C(O)C(=O)C=C(OC)C1=O  Polyketides      7
# 47337              CCCCCCCCCCCCCCCC1=C(O)C(=O)C=C(O)C1=O  Polyketides      7
# 47338                CCCCCCCCCCCCCC1=C(O)C(=O)C=C(O)C1=O  Polyketides      7
#
# [47339 rows x 3 columns]

# %%
df['Class'].value_counts()
# Out:
# 0    10550
# 2    10018
# 1     7739
# 7     7145
# 3     4533
# 4     3627
# 5     2382
# 6     1345
# Name: Class, dtype: int64

# %%
X_train, X_test = train_test_split(df, 
                                   test_size=0.2, 
                                   shuffle=True, 
                                   stratify=df['Class'], 
                                   random_state=args.seed)
X_train = X_train.reset_index(drop=True)
X_test = X_test.reset_index(drop=True)
len(X_train), len(X_test)
# Out:
# (37871, 9468)

# %%
train_mols = make_mol(X_train)
test_mols = make_mol(X_test)

train_X = make_vec(train_mols)
test_X = make_vec(test_mols)

len(train_X), len(test_X)
# Out:
# (37871, 9468)

# %%
class GCNlayer(nn.Module):
    
    def __init__(self, n_features, conv_dim1, conv_dim2, conv_dim3, concat_dim, dropout):
        super(GCNlayer, self).__init__()
        self.dropout = dropout
        
        self.conv1 = GCNConv(n_features, conv_dim1)
        self.bn1 = BatchNorm1d(conv_dim1)
        self.conv2 = GCNConv(conv_dim1, conv_dim2)
        self.bn2 = BatchNorm1d(conv_dim2)
        self.conv3 = GCNConv(conv_dim2, conv_dim3)
        self.bn3 = BatchNorm1d(conv_dim3)
        self.conv4 = GCNConv(conv_dim3, concat_dim)
        
        
    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = F.relu(self.conv1(x, edge_index))
        x = F.dropout(self.bn1(x), p=self.dropout)
        x = F.relu(self.conv2(x, edge_index))
        x = F.dropout(self.bn2(x), p=self.dropout)
        x = F.dropout(x, p=self.dropout)
        x = F.relu(self.conv3(x, edge_index))
        x = F.dropout(self.bn3(x), p=self.dropout)
        x = F.relu(self.conv4(x, edge_index))
        x = global_add_pool(x, data.batch)
        return x
    
class FClayer(nn.Module):
    
    def __init__(self, concat_dim, pred_dim1, pred_dim2, pred_dim3, out_dim, dropout):
        super(FClayer, self).__init__()
        self.dropout = dropout

        self.fc1 = Linear(concat_dim, pred_dim1)
        self.bn1 = BatchNorm1d(pred_dim1)
        self.fc2 = Linear(pred_dim1, pred_dim2)
        self.bn2 = BatchNorm1d(pred_dim2)
        self.fc3 = Linear(pred_dim2, pred_dim3)
        self.bn3 = BatchNorm1d(pred_dim3)
        self.fc4 = Linear(pred_dim3, out_dim)
    
    def forward(self, data):
        x = F.relu(self.fc1(data))
        x = F.dropout(self.bn1(x), p=self.dropout)
        x = F.relu(self.fc2(x))
        x = F.dropout(self.bn2(x), p=self.dropout)
        x = F.relu(self.fc3(x))
        x = F.dropout(self.bn3(x), p=self.dropout)
        x = self.fc4(x)
        return x
    
class Net(nn.Module):
    def __init__(self, args):
        super(Net, self).__init__()
        self.conv = GCNlayer(args.n_features, 
                              args.conv_dim1, 
                              args.conv_dim2, 
                              args.conv_dim3, 
                              args.concat_dim, 
                              args.dropout)
        self.fc = FClayer(args.concat_dim, 
                          args.pred_dim1, 
                          args.pred_dim2, 
                          args.pred_dim3, 
                          args.out_dim, 
                          args.dropout)
        
    def forward(self, data):
        x = self.conv(data)
        x = self.fc(x)
        x = F.log_softmax(x, dim=1)
        return x

# %%
class EarlyStopping:
    def __init__(self, patience=20, verbose=False, delta=0):
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.Inf
        self.delta = delta

    def __call__(self, val_loss, model):
        score = -val_loss
        if self.best_score is None:
            self.best_score = score
        elif score < self.best_score + self.delta:
            self.counter += 1
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.counter = 0

# %%
def train(model, device, optimizer, train_loader, criterion, args, prints):
    y_true = []
    y_pred = []
    epoch_loss = 0
    for i, data in enumerate(train_loader):
        data = data.to(device)
        labels = data.y.to(device)
        outputs = model(data)
        loss = criterion(outputs, labels)
        epoch_loss += loss
        optimizer.zero_grad()
        loss.backward()
        y_pred.extend(outputs.cpu().detach().max(axis=1).indices.tolist())
        y_true.extend(labels.cpu().detach().tolist())
    epoch_loss /= len(train_loader)
    return model, epoch_loss.tolist(), y_true, y_pred

def test(model, device, test_loader, criterion, args, prints):
    y_true = []
    y_pred = []
    epoch_loss = 0
    model.eval()
    with torch.no_grad():
        for i, data in enumerate(test_loader):
            data = data.to(device)
            labels = data.y.to(device)
            outputs = model(data)
            loss = criterion(outputs, labels)
            epoch_loss += loss
            y_pred.extend(outputs.cpu().detach().max(axis=1).indices.tolist())
            y_true.extend(labels.cpu().detach().tolist())
    epoch_loss /= len(train_loader)
    return model, epoch_loss.tolist(), y_true, y_pred

def results(true, pred):
    cm = confusion_matrix(true, pred)
    micf1 = f1_score(true, pred, average='micro')
    macf1 = f1_score(true, pred, average='macro')
    print('Micro F1 Score : %.2f' % micf1)
    print('Macro F1 Score : %.2f' % macf1)
    return cm, micf1, macf1

def experiment(model, train_loader, test_loader, device, args, prints=True):
    
    optimizer = optim.Adam(model.parameters(),lr=args.lr)
    criterion = nn.CrossEntropyLoss()
    scheduler = optim.lr_scheduler.StepLR(optimizer,
                                          step_size=args.step_size,
                                          gamma=args.gamma)
    early_stopping = EarlyStopping(patience=args.patience, verbose=True)
    
    list_train_loss = []
    list_test_loss = []
    if prints:
        print('[Train]')
    for epoch in range(args.epoch):
        optimizer.step()
        scheduler.step()
        model, train_loss, _, _ = train(model, device, optimizer, train_loader, criterion, args, prints)
        model, test_loss, y_true, y_pred = test(model, device, test_loader, criterion, args, prints)
        list_train_loss.append(train_loss)
        list_test_loss.append(test_loss)
        if prints:
            print('- Epoch: %d\t- Train Loss: %.4f\t- Test Loss: %.4f' % (epoch+1, train_loss, test_loss))
        early_stopping(test_loss, model)
        if early_stopping.early_stop:
            print("Early stopping")
            break
    if prints:
        print('[Tets]')
    model, test_loss, y_true, y_pred = test(model, device, test_loader, criterion, args, prints)
    
    cm, micf1, macf1 = results(y_true, y_pred)
    
    args.list_train_loss = list_train_loss
    args.list_test_loss = list_test_loss
    args.y_true = y_true
    args.y_pred = y_pred
    args.cm = cm
    args.micf1 = micf1
    args.macf1 = macf1
    
    return args

# %%
def plot_result(result_df):
    
    figsize = 4
    label_fs = 14
    legend_fs = 12
    ticks_fs = 12

    train_loss = result_df['list_train_loss'].iloc[0]
    test_loss = result_df['list_test_loss'].iloc[0]
    y_true = result_df['y_true'].iloc[0]
    y_pred = result_df['y_pred'].iloc[0]
    classes = result_df['classes'].iloc[0]
    cm, micf1, macf1 = results(y_true, y_pred)
    
    cm_matrix = pd.DataFrame(cm, 
                             index=classes, 
                             columns=classes)
    plt.figure(figsize=(figsize+1, figsize))
    sns.heatmap(cm_matrix.astype('int'), annot=True, cmap='Blues', fmt="d", 
               xticklabels=classes, yticklabels=classes, annot_kws={"size": 8})
    plt.tick_params(left=False, bottom=False)
    plt.xlabel('Predicted Class', fontsize=label_fs)
    plt.ylabel('True Class', fontsize=label_fs)
    plt.xticks(fontsize=ticks_fs)
    plt.yticks(fontsize=ticks_fs)
    plt.show()
    
    plt.figure(figsize=(figsize, figsize))
    plt.plot([e for e in range(len(train_loss))], [float(t) for t in train_loss], label="Train Loss", c='blue')
    plt.plot([e for e in range(len(train_loss))], [float(t) for t in test_loss], label="Test Loss", c='red')
    plt.xlabel("Epoch", fontsize=label_fs)
    plt.ylabel("Loss", fontsize=label_fs)
    plt.xticks(fontsize=ticks_fs)
    plt.yticks(fontsize=ticks_fs)
    plt.legend(fontsize=legend_fs)
    plt.show()
    
    return cm, micf1, macf1

# %%
args.batch_size = 512
args.optim = 'Adam'
args.step_size = 10
args.gamma = 0.9
args.dropout = 0.2
args.lr = 0.0001
args.epoch = 1000
args.patience = 50
args.n_features = 27
conv_dim = 128
args.conv_dim1 = conv_dim
args.conv_dim2 = conv_dim
args.conv_dim3 = conv_dim
args.concat_dim = 128
args.pred_dim1 = 128
args.pred_dim2 = 64
args.pred_dim3 = 32
args.out_dim = len(classes)
args.classes = [k for k in classes.keys()]

model = Net(args)
model = model.to(device)

train_loader = DataLoader(train_X, batch_size=args.batch_size, shuffle=True, drop_last=False)
test_loader = DataLoader(test_X, batch_size=args.batch_size, shuffle=False, drop_last=False)

dict_result = dict()
args.exp_name = f'Exp'
result = vars(experiment(model, train_loader, test_loader, device, args, prints=True))
dict_result[args.exp_name] = copy.deepcopy(result)
torch.cuda.empty_cache()

result_df = pd.DataFrame(dict_result).transpose()
result_df.to_csv(f'./result.csv', index=False)
# Out:
# [Train]
# - Epoch: 1	- Train Loss: 2.2060	- Test Loss: 0.5648
# - Epoch: 2	- Train Loss: 2.1595	- Test Loss: 0.5553
# - Epoch: 3	- Train Loss: 2.1027	- Test Loss: 0.5417
# - Epoch: 4	- Train Loss: 2.0423	- Test Loss: 0.5240
# - Epoch: 5	- Train Loss: 1.9861	- Test Loss: 0.5123
# - Epoch: 6	- Train Loss: 1.9452	- Test Loss: 0.4991
# - Epoch: 7	- Train Loss: 1.8989	- Test Loss: 0.4861
# - Epoch: 8	- Train Loss: 1.8553	- Test Loss: 0.4779
# - Epoch: 9	- Train Loss: 1.8212	- Test Loss: 0.4712
# - Epoch: 10	- Train Loss: 1.7821	- Test Loss: 0.4576
# - Epoch: 11	- Train Loss: 1.7533	- Test Loss: 0.4523
# - Epoch: 12	- Train Loss: 1.7281	- Test Loss: 0.4464
# - Epoch: 13	- Train Loss: 1.6977	- Test Loss: 0.4375
# - Epoch: 14	- Train Loss: 1.6697	- Test Loss: 0.4330
# - Epoch: 15	- Train Loss: 1.6426	- Test Loss: 0.4242
# - Epoch: 16	- Train Loss: 1.6196	- Test Loss: 0.4179
# - Epoch: 17	- Train Loss: 1.5947	- Test Loss: 0.4088
# - Epoch: 18	- Train Loss: 1.5725	- Test Loss: 0.4065
# - Epoch: 19	- Train Loss: 1.5511	- Test Loss: 0.3997
# - Epoch: 20	- Train Loss: 1.5231	- Test Loss: 0.3947
# - Epoch: 21	- Train Loss: 1.5051	- Test Loss: 0.3900
# - Epoch: 22	- Train Loss: 1.4888	- Test Loss: 0.3850
# - Epoch: 23	- Train Loss: 1.4684	- Test Loss: 0.3815
# - Epoch: 24	- Train Loss: 1.4554	- Test Loss: 0.3742
# - Epoch: 25	- Train Loss: 1.4425	- Test Loss: 0.3711
# - Epoch: 26	- Train Loss: 1.4195	- Test Loss: 0.3686
# - Epoch: 27	- Train Loss: 1.4024	- Test Loss: 0.3635
# - Epoch: 28	- Train Loss: 1.3854	- Test Loss: 0.3597
# - Epoch: 29	- Train Loss: 1.3673	- Test Loss: 0.3560
# - Epoch: 30	- Train Loss: 1.3509	- Test Loss: 0.3482
# - Epoch: 31	- Train Loss: 1.3381	- Test Loss: 0.3456
# - Epoch: 32	- Train Loss: 1.3239	- Test Loss: 0.3406
# - Epoch: 33	- Train Loss: 1.3093	- Test Loss: 0.3401
# - Epoch: 34	- Train Loss: 1.2995	- Test Loss: 0.3372
# - Epoch: 35	- Train Loss: 1.2841	- Test Loss: 0.3304
# - Epoch: 36	- Train Loss: 1.2714	- Test Loss: 0.3303
# - Epoch: 37	- Train Loss: 1.2585	- Test Loss: 0.3257
# - Epoch: 38	- Train Loss: 1.2379	- Test Loss: 0.3224
# - Epoch: 39	- Train Loss: 1.2248	- Test Loss: 0.3197
# - Epoch: 40	- Train Loss: 1.2141	- Test Loss: 0.3153
# - Epoch: 41	- Train Loss: 1.2076	- Test Loss: 0.3108
# - Epoch: 42	- Train Loss: 1.1913	- Test Loss: 0.3102
# - Epoch: 43	- Train Loss: 1.1879	- Test Loss: 0.3079
# - Epoch: 44	- Train Loss: 1.1754	- Test Loss: 0.3052
# - Epoch: 45	- Train Loss: 1.1638	- Test Loss: 0.2984
# - Epoch: 46	- Train Loss: 1.1518	- Test Loss: 0.2987
# - Epoch: 47	- Train Loss: 1.1456	- Test Loss: 0.2989
# - Epoch: 48	- Train Loss: 1.1359	- Test Loss: 0.2952
# - Epoch: 49	- Train Loss: 1.1234	- Test Loss: 0.2921
# - Epoch: 50	- Train Loss: 1.1136	- Test Loss: 0.2891
# - Epoch: 51	- Train Loss: 1.1033	- Test Loss: 0.2877
# - Epoch: 52	- Train Loss: 1.1002	- Test Loss: 0.2840
# - Epoch: 53	- Train Loss: 1.0884	- Test Loss: 0.2843
# - Epoch: 54	- Train Loss: 1.0817	- Test Loss: 0.2820
# - Epoch: 55	- Train Loss: 1.0693	- Test Loss: 0.2752
# - Epoch: 56	- Train Loss: 1.0603	- Test Loss: 0.2758
# - Epoch: 57	- Train Loss: 1.0571	- Test Loss: 0.2735
# - Epoch: 58	- Train Loss: 1.0450	- Test Loss: 0.2733
# - Epoch: 59	- Train Loss: 1.0395	- Test Loss: 0.2688
# - Epoch: 60	- Train Loss: 1.0300	- Test Loss: 0.2687
# - Epoch: 61	- Train Loss: 1.0242	- Test Loss: 0.2671
# - Epoch: 62	- Train Loss: 1.0216	- Test Loss: 0.2639
# - Epoch: 63	- Train Loss: 1.0121	- Test Loss: 0.2620
# - Epoch: 64	- Train Loss: 1.0022	- Test Loss: 0.2630
# - Epoch: 65	- Train Loss: 0.9987	- Test Loss: 0.2606
# - Epoch: 66	- Train Loss: 0.9945	- Test Loss: 0.2556
# - Epoch: 67	- Train Loss: 0.9823	- Test Loss: 0.2535
# - Epoch: 68	- Train Loss: 0.9810	- Test Loss: 0.2528
# - Epoch: 69	- Train Loss: 0.9727	- Test Loss: 0.2535
# - Epoch: 70	- Train Loss: 0.9617	- Test Loss: 0.2530
# - Epoch: 71	- Train Loss: 0.9586	- Test Loss: 0.2508
# - Epoch: 72	- Train Loss: 0.9542	- Test Loss: 0.2453
# - Epoch: 73	- Train Loss: 0.9483	- Test Loss: 0.2461
# - Epoch: 74	- Train Loss: 0.9427	- Test Loss: 0.2455
# - Epoch: 75	- Train Loss: 0.9380	- Test Loss: 0.2437
# - Epoch: 76	- Train Loss: 0.9285	- Test Loss: 0.2438
# - Epoch: 77	- Train Loss: 0.9252	- Test Loss: 0.2407
# - Epoch: 78	- Train Loss: 0.9249	- Test Loss: 0.2393
# - Epoch: 79	- Train Loss: 0.9188	- Test Loss: 0.2356
# - Epoch: 80	- Train Loss: 0.9122	- Test Loss: 0.2359
# - Epoch: 81	- Train Loss: 0.9073	- Test Loss: 0.2357
# - Epoch: 82	- Train Loss: 0.8933	- Test Loss: 0.2308
# - Epoch: 83	- Train Loss: 0.8988	- Test Loss: 0.2300
# - Epoch: 84	- Train Loss: 0.8920	- Test Loss: 0.2312
# - Epoch: 85	- Train Loss: 0.8819	- Test Loss: 0.2291
# - Epoch: 86	- Train Loss: 0.8797	- Test Loss: 0.2282
# - Epoch: 87	- Train Loss: 0.8783	- Test Loss: 0.2321
# - Epoch: 88	- Train Loss: 0.8710	- Test Loss: 0.2268
# - Epoch: 89	- Train Loss: 0.8660	- Test Loss: 0.2267
# - Epoch: 90	- Train Loss: 0.8625	- Test Loss: 0.2239
# - Epoch: 91	- Train Loss: 0.8573	- Test Loss: 0.2242
# - Epoch: 92	- Train Loss: 0.8610	- Test Loss: 0.2208
# - Epoch: 93	- Train Loss: 0.8500	- Test Loss: 0.2218
# - Epoch: 94	- Train Loss: 0.8465	- Test Loss: 0.2196
# - Epoch: 95	- Train Loss: 0.8432	- Test Loss: 0.2216
# - Epoch: 96	- Train Loss: 0.8366	- Test Loss: 0.2192
# - Epoch: 97	- Train Loss: 0.8356	- Test Loss: 0.2183
# - Epoch: 98	- Train Loss: 0.8264	- Test Loss: 0.2171
# - Epoch: 99	- Train Loss: 0.8287	- Test Loss: 0.2150
# - Epoch: 100	- Train Loss: 0.8158	- Test Loss: 0.2124
# - Epoch: 101	- Train Loss: 0.8177	- Test Loss: 0.2131
# - Epoch: 102	- Train Loss: 0.8205	- Test Loss: 0.2096
# - Epoch: 103	- Train Loss: 0.8119	- Test Loss: 0.2095
# - Epoch: 104	- Train Loss: 0.8102	- Test Loss: 0.2123
# - Epoch: 105	- Train Loss: 0.8070	- Test Loss: 0.2100
# - Epoch: 106	- Train Loss: 0.8093	- Test Loss: 0.2090
# - Epoch: 107	- Train Loss: 0.8000	- Test Loss: 0.2081
# - Epoch: 108	- Train Loss: 0.7944	- Test Loss: 0.2052
# - Epoch: 109	- Train Loss: 0.7951	- Test Loss: 0.2055
# - Epoch: 110	- Train Loss: 0.7933	- Test Loss: 0.2050
# - Epoch: 111	- Train Loss: 0.7888	- Test Loss: 0.2046
# - Epoch: 112	- Train Loss: 0.7806	- Test Loss: 0.2039
# - Epoch: 113	- Train Loss: 0.7837	- Test Loss: 0.2026
# - Epoch: 114	- Train Loss: 0.7766	- Test Loss: 0.2033
# - Epoch: 115	- Train Loss: 0.7772	- Test Loss: 0.2031
# - Epoch: 116	- Train Loss: 0.7706	- Test Loss: 0.2013
# - Epoch: 117	- Train Loss: 0.7708	- Test Loss: 0.1969
# - Epoch: 118	- Train Loss: 0.7724	- Test Loss: 0.1994
# - Epoch: 119	- Train Loss: 0.7624	- Test Loss: 0.1987
# - Epoch: 120	- Train Loss: 0.7640	- Test Loss: 0.1984
# - Epoch: 121	- Train Loss: 0.7604	- Test Loss: 0.1974
# - Epoch: 122	- Train Loss: 0.7563	- Test Loss: 0.1946
# - Epoch: 123	- Train Loss: 0.7572	- Test Loss: 0.1956
# - Epoch: 124	- Train Loss: 0.7543	- Test Loss: 0.1980
# - Epoch: 125	- Train Loss: 0.7500	- Test Loss: 0.1927
# - Epoch: 126	- Train Loss: 0.7488	- Test Loss: 0.1953
# - Epoch: 127	- Train Loss: 0.7487	- Test Loss: 0.1959
# - Epoch: 128	- Train Loss: 0.7465	- Test Loss: 0.1931
# - Epoch: 129	- Train Loss: 0.7463	- Test Loss: 0.1926
# - Epoch: 130	- Train Loss: 0.7380	- Test Loss: 0.1918
# - Epoch: 131	- Train Loss: 0.7332	- Test Loss: 0.1922
# - Epoch: 132	- Train Loss: 0.7319	- Test Loss: 0.1917
# - Epoch: 133	- Train Loss: 0.7325	- Test Loss: 0.1918
# - Epoch: 134	- Train Loss: 0.7281	- Test Loss: 0.1907
# - Epoch: 135	- Train Loss: 0.7323	- Test Loss: 0.1918
# - Epoch: 136	- Train Loss: 0.7224	- Test Loss: 0.1897
# - Epoch: 137	- Train Loss: 0.7250	- Test Loss: 0.1891
# - Epoch: 138	- Train Loss: 0.7249	- Test Loss: 0.1880
# - Epoch: 139	- Train Loss: 0.7235	- Test Loss: 0.1908
# - Epoch: 140	- Train Loss: 0.7165	- Test Loss: 0.1861
# - Epoch: 141	- Train Loss: 0.7188	- Test Loss: 0.1859
# - Epoch: 142	- Train Loss: 0.7161	- Test Loss: 0.1875
# - Epoch: 143	- Train Loss: 0.7171	- Test Loss: 0.1855
# - Epoch: 144	- Train Loss: 0.7119	- Test Loss: 0.1889
# - Epoch: 145	- Train Loss: 0.7092	- Test Loss: 0.1883
# - Epoch: 146	- Train Loss: 0.7078	- Test Loss: 0.1838
# - Epoch: 147	- Train Loss: 0.7064	- Test Loss: 0.1868
# - Epoch: 148	- Train Loss: 0.7058	- Test Loss: 0.1846
# - Epoch: 149	- Train Loss: 0.7055	- Test Loss: 0.1842
# - Epoch: 150	- Train Loss: 0.7036	- Test Loss: 0.1816
# - Epoch: 151	- Train Loss: 0.7052	- Test Loss: 0.1824
# - Epoch: 152	- Train Loss: 0.7018	- Test Loss: 0.1794
# - Epoch: 153	- Train Loss: 0.7014	- Test Loss: 0.1806
# - Epoch: 154	- Train Loss: 0.6945	- Test Loss: 0.1823
# - Epoch: 155	- Train Loss: 0.6913	- Test Loss: 0.1803
# - Epoch: 156	- Train Loss: 0.6910	- Test Loss: 0.1805
# - Epoch: 157	- Train Loss: 0.6926	- Test Loss: 0.1785
# - Epoch: 158	- Train Loss: 0.6908	- Test Loss: 0.1773
# - Epoch: 159	- Train Loss: 0.6947	- Test Loss: 0.1792
# - Epoch: 160	- Train Loss: 0.6889	- Test Loss: 0.1785
# - Epoch: 161	- Train Loss: 0.6879	- Test Loss: 0.1811
# - Epoch: 162	- Train Loss: 0.6849	- Test Loss: 0.1797
# - Epoch: 163	- Train Loss: 0.6848	- Test Loss: 0.1784
# - Epoch: 164	- Train Loss: 0.6814	- Test Loss: 0.1784
# - Epoch: 165	- Train Loss: 0.6834	- Test Loss: 0.1770
# - Epoch: 166	- Train Loss: 0.6795	- Test Loss: 0.1778
# - Epoch: 167	- Train Loss: 0.6769	- Test Loss: 0.1785
# - Epoch: 168	- Train Loss: 0.6717	- Test Loss: 0.1801
# - Epoch: 169	- Train Loss: 0.6790	- Test Loss: 0.1754
# - Epoch: 170	- Train Loss: 0.6769	- Test Loss: 0.1768
# - Epoch: 171	- Train Loss: 0.6724	- Test Loss: 0.1753
# - Epoch: 172	- Train Loss: 0.6747	- Test Loss: 0.1782
# - Epoch: 173	- Train Loss: 0.6731	- Test Loss: 0.1803
# - Epoch: 174	- Train Loss: 0.6737	- Test Loss: 0.1738
# - Epoch: 175	- Train Loss: 0.6722	- Test Loss: 0.1752
# - Epoch: 176	- Train Loss: 0.6688	- Test Loss: 0.1728
# - Epoch: 177	- Train Loss: 0.6722	- Test Loss: 0.1727
# - Epoch: 178	- Train Loss: 0.6666	- Test Loss: 0.1756
# - Epoch: 179	- Train Loss: 0.6636	- Test Loss: 0.1770
# - Epoch: 180	- Train Loss: 0.6645	- Test Loss: 0.1762
# - Epoch: 181	- Train Loss: 0.6688	- Test Loss: 0.1722
# - Epoch: 182	- Train Loss: 0.6604	- Test Loss: 0.1712
# - Epoch: 183	- Train Loss: 0.6578	- Test Loss: 0.1734
# - Epoch: 184	- Train Loss: 0.6613	- Test Loss: 0.1719
# - Epoch: 185	- Train Loss: 0.6567	- Test Loss: 0.1729
# - Epoch: 186	- Train Loss: 0.6572	- Test Loss: 0.1731
# - Epoch: 187	- Train Loss: 0.6585	- Test Loss: 0.1732
# - Epoch: 188	- Train Loss: 0.6549	- Test Loss: 0.1722
# - Epoch: 189	- Train Loss: 0.6567	- Test Loss: 0.1716
# - Epoch: 190	- Train Loss: 0.6470	- Test Loss: 0.1707
# - Epoch: 191	- Train Loss: 0.6506	- Test Loss: 0.1708
# - Epoch: 192	- Train Loss: 0.6519	- Test Loss: 0.1697
# - Epoch: 193	- Train Loss: 0.6560	- Test Loss: 0.1709
# - Epoch: 194	- Train Loss: 0.6498	- Test Loss: 0.1719
# - Epoch: 195	- Train Loss: 0.6488	- Test Loss: 0.1707
# - Epoch: 196	- Train Loss: 0.6493	- Test Loss: 0.1710
# - Epoch: 197	- Train Loss: 0.6475	- Test Loss: 0.1695
# - Epoch: 198	- Train Loss: 0.6447	- Test Loss: 0.1681
# - Epoch: 199	- Train Loss: 0.6497	- Test Loss: 0.1695
# - Epoch: 200	- Train Loss: 0.6503	- Test Loss: 0.1697
# - Epoch: 201	- Train Loss: 0.6449	- Test Loss: 0.1693
# - Epoch: 202	- Train Loss: 0.6444	- Test Loss: 0.1671
# - Epoch: 203	- Train Loss: 0.6424	- Test Loss: 0.1653
# - Epoch: 204	- Train Loss: 0.6479	- Test Loss: 0.1691
# - Epoch: 205	- Train Loss: 0.6438	- Test Loss: 0.1650
# - Epoch: 206	- Train Loss: 0.6413	- Test Loss: 0.1679
# - Epoch: 207	- Train Loss: 0.6438	- Test Loss: 0.1682
# - Epoch: 208	- Train Loss: 0.6384	- Test Loss: 0.1683
# - Epoch: 209	- Train Loss: 0.6362	- Test Loss: 0.1656
# - Epoch: 210	- Train Loss: 0.6370	- Test Loss: 0.1671
# - Epoch: 211	- Train Loss: 0.6361	- Test Loss: 0.1651
# - Epoch: 212	- Train Loss: 0.6363	- Test Loss: 0.1677
# - Epoch: 213	- Train Loss: 0.6389	- Test Loss: 0.1653
# - Epoch: 214	- Train Loss: 0.6371	- Test Loss: 0.1629
# - Epoch: 215	- Train Loss: 0.6359	- Test Loss: 0.1642
# - Epoch: 216	- Train Loss: 0.6357	- Test Loss: 0.1648
# - Epoch: 217	- Train Loss: 0.6336	- Test Loss: 0.1675
# - Epoch: 218	- Train Loss: 0.6340	- Test Loss: 0.1657
# - Epoch: 219	- Train Loss: 0.6361	- Test Loss: 0.1642
# - Epoch: 220	- Train Loss: 0.6305	- Test Loss: 0.1636
# - Epoch: 221	- Train Loss: 0.6403	- Test Loss: 0.1634
# - Epoch: 222	- Train Loss: 0.6326	- Test Loss: 0.1633
# - Epoch: 223	- Train Loss: 0.6348	- Test Loss: 0.1644
# - Epoch: 224	- Train Loss: 0.6286	- Test Loss: 0.1649
# - Epoch: 225	- Train Loss: 0.6290	- Test Loss: 0.1630
# - Epoch: 226	- Train Loss: 0.6304	- Test Loss: 0.1659
# - Epoch: 227	- Train Loss: 0.6277	- Test Loss: 0.1652
# - Epoch: 228	- Train Loss: 0.6300	- Test Loss: 0.1636
# - Epoch: 229	- Train Loss: 0.6261	- Test Loss: 0.1639
# - Epoch: 230	- Train Loss: 0.6248	- Test Loss: 0.1622
# - Epoch: 231	- Train Loss: 0.6272	- Test Loss: 0.1595
# - Epoch: 232	- Train Loss: 0.6311	- Test Loss: 0.1646
# - Epoch: 233	- Train Loss: 0.6278	- Test Loss: 0.1645
# - Epoch: 234	- Train Loss: 0.6201	- Test Loss: 0.1648
# - Epoch: 235	- Train Loss: 0.6248	- Test Loss: 0.1618
# - Epoch: 236	- Train Loss: 0.6270	- Test Loss: 0.1626
# - Epoch: 237	- Train Loss: 0.6219	- Test Loss: 0.1633
# - Epoch: 238	- Train Loss: 0.6235	- Test Loss: 0.1646
# - Epoch: 239	- Train Loss: 0.6200	- Test Loss: 0.1652
# - Epoch: 240	- Train Loss: 0.6178	- Test Loss: 0.1609
# - Epoch: 241	- Train Loss: 0.6221	- Test Loss: 0.1632
# - Epoch: 242	- Train Loss: 0.6232	- Test Loss: 0.1616
# - Epoch: 243	- Train Loss: 0.6205	- Test Loss: 0.1647
# - Epoch: 244	- Train Loss: 0.6209	- Test Loss: 0.1617
# - Epoch: 245	- Train Loss: 0.6175	- Test Loss: 0.1600
# - Epoch: 246	- Train Loss: 0.6184	- Test Loss: 0.1620
# - Epoch: 247	- Train Loss: 0.6126	- Test Loss: 0.1626
# - Epoch: 248	- Train Loss: 0.6209	- Test Loss: 0.1618
# - Epoch: 249	- Train Loss: 0.6176	- Test Loss: 0.1595
# - Epoch: 250	- Train Loss: 0.6197	- Test Loss: 0.1609
# - Epoch: 251	- Train Loss: 0.6145	- Test Loss: 0.1616
# - Epoch: 252	- Train Loss: 0.6178	- Test Loss: 0.1577
# - Epoch: 253	- Train Loss: 0.6186	- Test Loss: 0.1600
# - Epoch: 254	- Train Loss: 0.6208	- Test Loss: 0.1622
# - Epoch: 255	- Train Loss: 0.6123	- Test Loss: 0.1591
# - Epoch: 256	- Train Loss: 0.6119	- Test Loss: 0.1639
# - Epoch: 257	- Train Loss: 0.6184	- Test Loss: 0.1610
# - Epoch: 258	- Train Loss: 0.6102	- Test Loss: 0.1631
# - Epoch: 259	- Train Loss: 0.6102	- Test Loss: 0.1584
# - Epoch: 260	- Train Loss: 0.6116	- Test Loss: 0.1623
# - Epoch: 261	- Train Loss: 0.6118	- Test Loss: 0.1603
# - Epoch: 262	- Train Loss: 0.6094	- Test Loss: 0.1574
# - Epoch: 263	- Train Loss: 0.6077	- Test Loss: 0.1582
# - Epoch: 264	- Train Loss: 0.6079	- Test Loss: 0.1598
# - Epoch: 265	- Train Loss: 0.6161	- Test Loss: 0.1595
# - Epoch: 266	- Train Loss: 0.6146	- Test Loss: 0.1583
# - Epoch: 267	- Train Loss: 0.6082	- Test Loss: 0.1572
# - Epoch: 268	- Train Loss: 0.6079	- Test Loss: 0.1569
# - Epoch: 269	- Train Loss: 0.6062	- Test Loss: 0.1577
# - Epoch: 270	- Train Loss: 0.6071	- Test Loss: 0.1575
# - Epoch: 271	- Train Loss: 0.6123	- Test Loss: 0.1584
# - Epoch: 272	- Train Loss: 0.6055	- Test Loss: 0.1578
# - Epoch: 273	- Train Loss: 0.6082	- Test Loss: 0.1569
# - Epoch: 274	- Train Loss: 0.6032	- Test Loss: 0.1587
# - Epoch: 275	- Train Loss: 0.6064	- Test Loss: 0.1587
# - Epoch: 276	- Train Loss: 0.6036	- Test Loss: 0.1581
# - Epoch: 277	- Train Loss: 0.5996	- Test Loss: 0.1569
# - Epoch: 278	- Train Loss: 0.6041	- Test Loss: 0.1589
# - Epoch: 279	- Train Loss: 0.6066	- Test Loss: 0.1581
# - Epoch: 280	- Train Loss: 0.5994	- Test Loss: 0.1596
# - Epoch: 281	- Train Loss: 0.6043	- Test Loss: 0.1569
# - Epoch: 282	- Train Loss: 0.6016	- Test Loss: 0.1570
# - Epoch: 283	- Train Loss: 0.6020	- Test Loss: 0.1574
# - Epoch: 284	- Train Loss: 0.6059	- Test Loss: 0.1551
# - Epoch: 285	- Train Loss: 0.6092	- Test Loss: 0.1584
# - Epoch: 286	- Train Loss: 0.6036	- Test Loss: 0.1587
# - Epoch: 287	- Train Loss: 0.6018	- Test Loss: 0.1577
# - Epoch: 288	- Train Loss: 0.6006	- Test Loss: 0.1567
# - Epoch: 289	- Train Loss: 0.5977	- Test Loss: 0.1570
# - Epoch: 290	- Train Loss: 0.6031	- Test Loss: 0.1567
# - Epoch: 291	- Train Loss: 0.5979	- Test Loss: 0.1579
# - Epoch: 292	- Train Loss: 0.6022	- Test Loss: 0.1570
# - Epoch: 293	- Train Loss: 0.5957	- Test Loss: 0.1589
# - Epoch: 294	- Train Loss: 0.6017	- Test Loss: 0.1560
# - Epoch: 295	- Train Loss: 0.5962	- Test Loss: 0.1561
# - Epoch: 296	- Train Loss: 0.6011	- Test Loss: 0.1571
# - Epoch: 297	- Train Loss: 0.5996	- Test Loss: 0.1559
# - Epoch: 298	- Train Loss: 0.6015	- Test Loss: 0.1560
# - Epoch: 299	- Train Loss: 0.6031	- Test Loss: 0.1564
# - Epoch: 300	- Train Loss: 0.5982	- Test Loss: 0.1572
# - Epoch: 301	- Train Loss: 0.5979	- Test Loss: 0.1570
# - Epoch: 302	- Train Loss: 0.5960	- Test Loss: 0.1551
# - Epoch: 303	- Train Loss: 0.5989	- Test Loss: 0.1539
# - Epoch: 304	- Train Loss: 0.5988	- Test Loss: 0.1538
# - Epoch: 305	- Train Loss: 0.6022	- Test Loss: 0.1545
# - Epoch: 306	- Train Loss: 0.5994	- Test Loss: 0.1524
# - Epoch: 307	- Train Loss: 0.6014	- Test Loss: 0.1562
# - Epoch: 308	- Train Loss: 0.5946	- Test Loss: 0.1572
# - Epoch: 309	- Train Loss: 0.5987	- Test Loss: 0.1548
# - Epoch: 310	- Train Loss: 0.5996	- Test Loss: 0.1546
# - Epoch: 311	- Train Loss: 0.5994	- Test Loss: 0.1568
# - Epoch: 312	- Train Loss: 0.6040	- Test Loss: 0.1582
# - Epoch: 313	- Train Loss: 0.6014	- Test Loss: 0.1571
# - Epoch: 314	- Train Loss: 0.5943	- Test Loss: 0.1542
# - Epoch: 315	- Train Loss: 0.5976	- Test Loss: 0.1575
# - Epoch: 316	- Train Loss: 0.5886	- Test Loss: 0.1544
# - Epoch: 317	- Train Loss: 0.5953	- Test Loss: 0.1558
# - Epoch: 318	- Train Loss: 0.5947	- Test Loss: 0.1534
# - Epoch: 319	- Train Loss: 0.5953	- Test Loss: 0.1554
# - Epoch: 320	- Train Loss: 0.5981	- Test Loss: 0.1551
# - Epoch: 321	- Train Loss: 0.5935	- Test Loss: 0.1530
# - Epoch: 322	- Train Loss: 0.5959	- Test Loss: 0.1553
# - Epoch: 323	- Train Loss: 0.5959	- Test Loss: 0.1552
# - Epoch: 324	- Train Loss: 0.5931	- Test Loss: 0.1568
# - Epoch: 325	- Train Loss: 0.5896	- Test Loss: 0.1555
# - Epoch: 326	- Train Loss: 0.5898	- Test Loss: 0.1552
# - Epoch: 327	- Train Loss: 0.5982	- Test Loss: 0.1564
# - Epoch: 328	- Train Loss: 0.5930	- Test Loss: 0.1562
# - Epoch: 329	- Train Loss: 0.5956	- Test Loss: 0.1554
# - Epoch: 330	- Train Loss: 0.5909	- Test Loss: 0.1546
# - Epoch: 331	- Train Loss: 0.5918	- Test Loss: 0.1545
# - Epoch: 332	- Train Loss: 0.5954	- Test Loss: 0.1545
# - Epoch: 333	- Train Loss: 0.5973	- Test Loss: 0.1557
# - Epoch: 334	- Train Loss: 0.5920	- Test Loss: 0.1562
# - Epoch: 335	- Train Loss: 0.5857	- Test Loss: 0.1533
# - Epoch: 336	- Train Loss: 0.5901	- Test Loss: 0.1547
# - Epoch: 337	- Train Loss: 0.5951	- Test Loss: 0.1550
# - Epoch: 338	- Train Loss: 0.5959	- Test Loss: 0.1552
# - Epoch: 339	- Train Loss: 0.5938	- Test Loss: 0.1556
# - Epoch: 340	- Train Loss: 0.5913	- Test Loss: 0.1540
# - Epoch: 341	- Train Loss: 0.5959	- Test Loss: 0.1532
# - Epoch: 342	- Train Loss: 0.5943	- Test Loss: 0.1556
# - Epoch: 343	- Train Loss: 0.5916	- Test Loss: 0.1549
# - Epoch: 344	- Train Loss: 0.5926	- Test Loss: 0.1529
# - Epoch: 345	- Train Loss: 0.5924	- Test Loss: 0.1535
# - Epoch: 346	- Train Loss: 0.5924	- Test Loss: 0.1550
# - Epoch: 347	- Train Loss: 0.5926	- Test Loss: 0.1535
# - Epoch: 348	- Train Loss: 0.5950	- Test Loss: 0.1526
# - Epoch: 349	- Train Loss: 0.5952	- Test Loss: 0.1549
# - Epoch: 350	- Train Loss: 0.5936	- Test Loss: 0.1550
# - Epoch: 351	- Train Loss: 0.5933	- Test Loss: 0.1552
# - Epoch: 352	- Train Loss: 0.5890	- Test Loss: 0.1533
# - Epoch: 353	- Train Loss: 0.5911	- Test Loss: 0.1538
# - Epoch: 354	- Train Loss: 0.5885	- Test Loss: 0.1547
# - Epoch: 355	- Train Loss: 0.5876	- Test Loss: 0.1521
# - Epoch: 356	- Train Loss: 0.5911	- Test Loss: 0.1534
# - Epoch: 357	- Train Loss: 0.5926	- Test Loss: 0.1534
# - Epoch: 358	- Train Loss: 0.5884	- Test Loss: 0.1529
# - Epoch: 359	- Train Loss: 0.5889	- Test Loss: 0.1548
# - Epoch: 360	- Train Loss: 0.5887	- Test Loss: 0.1534
# - Epoch: 361	- Train Loss: 0.5897	- Test Loss: 0.1537
# - Epoch: 362	- Train Loss: 0.5896	- Test Loss: 0.1523
# - Epoch: 363	- Train Loss: 0.5866	- Test Loss: 0.1541
# - Epoch: 364	- Train Loss: 0.5840	- Test Loss: 0.1513
# - Epoch: 365	- Train Loss: 0.5862	- Test Loss: 0.1552
# - Epoch: 366	- Train Loss: 0.5879	- Test Loss: 0.1557
# - Epoch: 367	- Train Loss: 0.5840	- Test Loss: 0.1528
# - Epoch: 368	- Train Loss: 0.5888	- Test Loss: 0.1526
# - Epoch: 369	- Train Loss: 0.5834	- Test Loss: 0.1543
# - Epoch: 370	- Train Loss: 0.5857	- Test Loss: 0.1523
# - Epoch: 371	- Train Loss: 0.5902	- Test Loss: 0.1542
# - Epoch: 372	- Train Loss: 0.5850	- Test Loss: 0.1539
# - Epoch: 373	- Train Loss: 0.5847	- Test Loss: 0.1502
# - Epoch: 374	- Train Loss: 0.5882	- Test Loss: 0.1568
# - Epoch: 375	- Train Loss: 0.5876	- Test Loss: 0.1534
# - Epoch: 376	- Train Loss: 0.5859	- Test Loss: 0.1512
# - Epoch: 377	- Train Loss: 0.5845	- Test Loss: 0.1511
# - Epoch: 378	- Train Loss: 0.5885	- Test Loss: 0.1531
# - Epoch: 379	- Train Loss: 0.5834	- Test Loss: 0.1553
# - Epoch: 380	- Train Loss: 0.5853	- Test Loss: 0.1529
# - Epoch: 381	- Train Loss: 0.5880	- Test Loss: 0.1506
# - Epoch: 382	- Train Loss: 0.5854	- Test Loss: 0.1542
# - Epoch: 383	- Train Loss: 0.5865	- Test Loss: 0.1520
# - Epoch: 384	- Train Loss: 0.5881	- Test Loss: 0.1506
# - Epoch: 385	- Train Loss: 0.5815	- Test Loss: 0.1538
# - Epoch: 386	- Train Loss: 0.5878	- Test Loss: 0.1530
# - Epoch: 387	- Train Loss: 0.5867	- Test Loss: 0.1510
# - Epoch: 388	- Train Loss: 0.5821	- Test Loss: 0.1527
# - Epoch: 389	- Train Loss: 0.5859	- Test Loss: 0.1514
# - Epoch: 390	- Train Loss: 0.5799	- Test Loss: 0.1547
# - Epoch: 391	- Train Loss: 0.5826	- Test Loss: 0.1528
# - Epoch: 392	- Train Loss: 0.5881	- Test Loss: 0.1533
# - Epoch: 393	- Train Loss: 0.5864	- Test Loss: 0.1514
# - Epoch: 394	- Train Loss: 0.5877	- Test Loss: 0.1513
# - Epoch: 395	- Train Loss: 0.5861	- Test Loss: 0.1524
# - Epoch: 396	- Train Loss: 0.5837	- Test Loss: 0.1521
# - Epoch: 397	- Train Loss: 0.5870	- Test Loss: 0.1532
# - Epoch: 398	- Train Loss: 0.5877	- Test Loss: 0.1504
# - Epoch: 399	- Train Loss: 0.5853	- Test Loss: 0.1537
# - Epoch: 400	- Train Loss: 0.5882	- Test Loss: 0.1523
# - Epoch: 401	- Train Loss: 0.5816	- Test Loss: 0.1510
# - Epoch: 402	- Train Loss: 0.5841	- Test Loss: 0.1515
# - Epoch: 403	- Train Loss: 0.5863	- Test Loss: 0.1496
# - Epoch: 404	- Train Loss: 0.5794	- Test Loss: 0.1506
# - Epoch: 405	- Train Loss: 0.5821	- Test Loss: 0.1524
# - Epoch: 406	- Train Loss: 0.5823	- Test Loss: 0.1515
# - Epoch: 407	- Train Loss: 0.5874	- Test Loss: 0.1524
# - Epoch: 408	- Train Loss: 0.5871	- Test Loss: 0.1545
# - Epoch: 409	- Train Loss: 0.5822	- Test Loss: 0.1516
# - Epoch: 410	- Train Loss: 0.5842	- Test Loss: 0.1522
# - Epoch: 411	- Train Loss: 0.5867	- Test Loss: 0.1509
# - Epoch: 412	- Train Loss: 0.5870	- Test Loss: 0.1552
# - Epoch: 413	- Train Loss: 0.5863	- Test Loss: 0.1520
# - Epoch: 414	- Train Loss: 0.5813	- Test Loss: 0.1550
# - Epoch: 415	- Train Loss: 0.5822	- Test Loss: 0.1517
# - Epoch: 416	- Train Loss: 0.5825	- Test Loss: 0.1518
# - Epoch: 417	- Train Loss: 0.5830	- Test Loss: 0.1554
# - Epoch: 418	- Train Loss: 0.5779	- Test Loss: 0.1527
# - Epoch: 419	- Train Loss: 0.5787	- Test Loss: 0.1505
# - Epoch: 420	- Train Loss: 0.5820	- Test Loss: 0.1526
# - Epoch: 421	- Train Loss: 0.5821	- Test Loss: 0.1530
# - Epoch: 422	- Train Loss: 0.5786	- Test Loss: 0.1524
# - Epoch: 423	- Train Loss: 0.5813	- Test Loss: 0.1533
# - Epoch: 424	- Train Loss: 0.5728	- Test Loss: 0.1554
# - Epoch: 425	- Train Loss: 0.5801	- Test Loss: 0.1499
# - Epoch: 426	- Train Loss: 0.5872	- Test Loss: 0.1512
# - Epoch: 427	- Train Loss: 0.5857	- Test Loss: 0.1539
# - Epoch: 428	- Train Loss: 0.5853	- Test Loss: 0.1531
# - Epoch: 429	- Train Loss: 0.5817	- Test Loss: 0.1517
# - Epoch: 430	- Train Loss: 0.5871	- Test Loss: 0.1511
# - Epoch: 431	- Train Loss: 0.5781	- Test Loss: 0.1495
# - Epoch: 432	- Train Loss: 0.5814	- Test Loss: 0.1502
# - Epoch: 433	- Train Loss: 0.5800	- Test Loss: 0.1504
# - Epoch: 434	- Train Loss: 0.5796	- Test Loss: 0.1535
# - Epoch: 435	- Train Loss: 0.5800	- Test Loss: 0.1513
# - Epoch: 436	- Train Loss: 0.5807	- Test Loss: 0.1487
# - Epoch: 437	- Train Loss: 0.5845	- Test Loss: 0.1511
# - Epoch: 438	- Train Loss: 0.5829	- Test Loss: 0.1510
# - Epoch: 439	- Train Loss: 0.5808	- Test Loss: 0.1518
# - Epoch: 440	- Train Loss: 0.5874	- Test Loss: 0.1516
# - Epoch: 441	- Train Loss: 0.5807	- Test Loss: 0.1494
# - Epoch: 442	- Train Loss: 0.5814	- Test Loss: 0.1521
# - Epoch: 443	- Train Loss: 0.5801	- Test Loss: 0.1522
# - Epoch: 444	- Train Loss: 0.5782	- Test Loss: 0.1530
# - Epoch: 445	- Train Loss: 0.5768	- Test Loss: 0.1509
# - Epoch: 446	- Train Loss: 0.5806	- Test Loss: 0.1528
# - Epoch: 447	- Train Loss: 0.5814	- Test Loss: 0.1511
# - Epoch: 448	- Train Loss: 0.5823	- Test Loss: 0.1491
# - Epoch: 449	- Train Loss: 0.5824	- Test Loss: 0.1501
# - Epoch: 450	- Train Loss: 0.5793	- Test Loss: 0.1532
# - Epoch: 451	- Train Loss: 0.5866	- Test Loss: 0.1502
# - Epoch: 452	- Train Loss: 0.5806	- Test Loss: 0.1529
# - Epoch: 453	- Train Loss: 0.5808	- Test Loss: 0.1521
# - Epoch: 454	- Train Loss: 0.5800	- Test Loss: 0.1523
# - Epoch: 455	- Train Loss: 0.5808	- Test Loss: 0.1507
# - Epoch: 456	- Train Loss: 0.5841	- Test Loss: 0.1529
# - Epoch: 457	- Train Loss: 0.5797	- Test Loss: 0.1512
# - Epoch: 458	- Train Loss: 0.5803	- Test Loss: 0.1515
# - Epoch: 459	- Train Loss: 0.5848	- Test Loss: 0.1514
# - Epoch: 460	- Train Loss: 0.5811	- Test Loss: 0.1513
# - Epoch: 461	- Train Loss: 0.5814	- Test Loss: 0.1517
# - Epoch: 462	- Train Loss: 0.5882	- Test Loss: 0.1517
# - Epoch: 463	- Train Loss: 0.5815	- Test Loss: 0.1513
# - Epoch: 464	- Train Loss: 0.5814	- Test Loss: 0.1520
# - Epoch: 465	- Train Loss: 0.5782	- Test Loss: 0.1535
# - Epoch: 466	- Train Loss: 0.5795	- Test Loss: 0.1513
# - Epoch: 467	- Train Loss: 0.5803	- Test Loss: 0.1487
# - Epoch: 468	- Train Loss: 0.5816	- Test Loss: 0.1527
# - Epoch: 469	- Train Loss: 0.5756	- Test Loss: 0.1498
# - Epoch: 470	- Train Loss: 0.5799	- Test Loss: 0.1519
# - Epoch: 471	- Train Loss: 0.5832	- Test Loss: 0.1508
# - Epoch: 472	- Train Loss: 0.5813	- Test Loss: 0.1506
# - Epoch: 473	- Train Loss: 0.5840	- Test Loss: 0.1548
# - Epoch: 474	- Train Loss: 0.5820	- Test Loss: 0.1497
# - Epoch: 475	- Train Loss: 0.5803	- Test Loss: 0.1512
# - Epoch: 476	- Train Loss: 0.5820	- Test Loss: 0.1503
# - Epoch: 477	- Train Loss: 0.5844	- Test Loss: 0.1511
# - Epoch: 478	- Train Loss: 0.5753	- Test Loss: 0.1488
# - Epoch: 479	- Train Loss: 0.5847	- Test Loss: 0.1499
# - Epoch: 480	- Train Loss: 0.5805	- Test Loss: 0.1542
# - Epoch: 481	- Train Loss: 0.5783	- Test Loss: 0.1526
# - Epoch: 482	- Train Loss: 0.5822	- Test Loss: 0.1515
# - Epoch: 483	- Train Loss: 0.5792	- Test Loss: 0.1513
# - Epoch: 484	- Train Loss: 0.5784	- Test Loss: 0.1497
# - Epoch: 485	- Train Loss: 0.5791	- Test Loss: 0.1508
# - Epoch: 486	- Train Loss: 0.5777	- Test Loss: 0.1527
# Early stopping
# [Tets]
# Micro F1 Score : 0.86
# Macro F1 Score : 0.81

# %%
cm, micf1, macf1 = plot_result(result_df)
# Out:
# Micro F1 Score : 0.86
# Macro F1 Score : 0.81
