# %%
import matplotlib.pyplot as plt
import seaborn as sns
from rdkit import Chem
import numpy as np
import pandas as pd
import copy
import argparse
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.nn import Linear
from torch.nn import BatchNorm1d
import torch.optim as optim
from torch.utils.data import Dataset
from torch_geometric.nn import GCNConv, GATConv
from torch_geometric.nn import global_add_pool
from torch_geometric.data import Data
from torch_geometric.loader import DataLoader
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score
import warnings
warnings.filterwarnings(action='ignore')

# %%
paser = argparse.ArgumentParser()
args = paser.parse_args("")
args.seed = 2023
    
np.random.seed(args.seed)
torch.manual_seed(args.seed)
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda', index=0)

# %%
def one_of_k_encoding_unk(x, allowable_set):
    if x not in allowable_set:
        x = allowable_set[-1]
    return list(map(lambda s: x == s, allowable_set))

def atom_features(atom):
    results = np.array(one_of_k_encoding_unk(atom.GetSymbol(), ['B', 'C', 'Cl', 'N', 'O', 'P', 'S']) + 
                       one_of_k_encoding_unk(atom.GetDegree(), [1, 2, 3, 4]) + 
                       one_of_k_encoding_unk(atom.GetImplicitValence(), [0, 1, 2, 3]) + 
                       [atom.GetFormalCharge(), atom.GetNumRadicalElectrons()] + 
                       one_of_k_encoding_unk(atom.GetHybridization(), [Chem.rdchem.HybridizationType.SP, 
                                                                       Chem.rdchem.HybridizationType.SP2, 
                                                                       Chem.rdchem.HybridizationType.SP3, 
                                                                       Chem.rdchem.HybridizationType.SP3D, 
                                                                       Chem.rdchem.HybridizationType.SP3D2]) + 
                       [atom.GetIsAromatic()]+
                       one_of_k_encoding_unk(atom.GetTotalNumHs(), [0, 1, 2, 3]))
    return results
 

def get_bond_pair(mol):
    bonds = mol.GetBonds()
    res = [[],[]]
    for bond in bonds:
        res[0] += [bond.GetBeginAtomIdx(), bond.GetEndAtomIdx()]
        res[1] += [bond.GetEndAtomIdx(), bond.GetBeginAtomIdx()]
    return res
 
def mol2vec(mol):
    atoms = mol.GetAtoms()
    node_feat= [atom_features(atom) for atom in atoms]
    edge_index = get_bond_pair(mol)
    data = Data(x=torch.tensor(node_feat, dtype=torch.float),
                edge_index=torch.tensor(edge_index, dtype=torch.long))
    return data

# %%
def make_mol(df):
    mols = {}
    for i in range(df.shape[0]):
        mols[Chem.MolFromSmiles(df['SMILES'].iloc[i])] = df['Class'].iloc[i]
    return mols

# %%
def make_vec(mols):
    X = [mol2vec(m) for m in mols.keys()]
    for i, data in enumerate(X):
        y = list(mols.values())[i]
        data.y = torch.tensor([y], dtype=torch.long)
    return X

# %%
df = pd.read_csv('./LMSD_Head_dataset.csv')
classes = {c:i for i,c in enumerate(df['Category'].unique())}
df['Class'] = 0
for i in range(df.shape[0]):
    df.loc[i, 'Class'] = classes[df['Category'].iloc[i]]
df
# Out:
#                                                   SMILES     Category  SP3_N  \
# 0      C=CCCCCC(C)CCCCCC#CCCC(OC)C(=O)OC(=O)C(CCC#CCC...  Fatty Acyls      0
# 1                 CCCCCCC[C@H](O)CC(=O)N[C@@H](CO)C(=O)O  Fatty Acyls      0
# 2      CCCCCCCCCCCCCCCC(=O)OC(CCCCCCCCCCCCCC)CC(=O)N[...  Fatty Acyls      1
# 3      CC/C=C\C/C=C\C/C=C\CCCCCCCC(=O)N[C@@H](CCC(N)=...  Fatty Acyls      0
# 4      CC(C)CCCCCCCCCCCCCC(=O)OC(CCCCCCCCCCCC(C)C)CC(...  Fatty Acyls      0
# ...                                                  ...          ...    ...
# 47065     CCCCCCCCCCC[C@H](CC1=CC(=O)C=C(OC)C1=O)OC(C)=O  Polyketides      0
# 47066                  CCCCCCCCCCCC1=C(O)C(=O)C=C(O)C1=O  Polyketides      0
# 47067                 CCCCCCCCCCCC1=C(O)C(=O)C=C(OC)C1=O  Polyketides      0
# 47068              CCCCCCCCCCCCCCCC1=C(O)C(=O)C=C(O)C1=O  Polyketides      0
# 47069                CCCCCCCCCCCCCC1=C(O)C(=O)C=C(O)C1=O  Polyketides      0
#
#                                 Head  Class
# 0                    O=C(CO)OC(=O)CO      0
# 1          O=C(CCO)N[C@@H](CO)C(=O)O      0
# 2      NCCC[C@H](NC(=O)CCOC=O)C(=O)O      0
# 3          NC(=O)CC[C@H](NC=O)C(=O)O      0
# 4       O=COCCC(=O)N[C@@H](CO)C(=O)O      0
# ...                              ...    ...
# 47065      O=COCCC1=CC(=O)C=C(O)C1=O      7
# 47066           O=C1C=C(O)C(=O)C=C1O      7
# 47067           O=C1C=C(O)C(=O)C=C1O      7
# 47068           O=C1C=C(O)C(=O)C=C1O      7
# 47069           O=C1C=C(O)C(=O)C=C1O      7
#
# [47070 rows x 5 columns]

# %%
df['Class'].value_counts()
# Out:
# 0    10335
# 2    10018
# 1     7739
# 7     7145
# 3     4533
# 4     3625
# 5     2330
# 6     1345
# Name: Class, dtype: int64

# %%
X_train, X_test = train_test_split(df, 
                                   test_size=0.2, 
                                   shuffle=True, 
                                   stratify=df['Class'], 
                                   random_state=args.seed)
X_train = X_train.reset_index(drop=True)
X_test = X_test.reset_index(drop=True)
len(X_train), len(X_test)
# Out:
# (37656, 9414)

# %%
train_mols = make_mol(X_train)
test_mols = make_mol(X_test)

train_X = make_vec(train_mols)
test_X = make_vec(test_mols)

len(train_X), len(test_X)
# Out:
# (37656, 9414)

# %%
class GCNlayer(nn.Module):
    
    def __init__(self, n_features, conv_dim1, conv_dim2, conv_dim3, concat_dim, dropout):
        super(GCNlayer, self).__init__()
        self.dropout = dropout
        
        self.conv1 = GCNConv(n_features, conv_dim1)
        self.bn1 = BatchNorm1d(conv_dim1)
        self.conv2 = GCNConv(conv_dim1, conv_dim2)
        self.bn2 = BatchNorm1d(conv_dim2)
        self.conv3 = GCNConv(conv_dim2, conv_dim3)
        self.bn3 = BatchNorm1d(conv_dim3)
        self.conv4 = GCNConv(conv_dim3, concat_dim)
        
        
    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = F.relu(self.conv1(x, edge_index))
        x = F.dropout(self.bn1(x), p=self.dropout)
        x = F.relu(self.conv2(x, edge_index))
        x = F.dropout(self.bn2(x), p=self.dropout)
        x = F.relu(self.conv3(x, edge_index))
        x = F.dropout(self.bn3(x), p=self.dropout)
        x = F.relu(self.conv4(x, edge_index))
        x = global_add_pool(x, data.batch)
        return x
    
class FClayer(nn.Module):
    
    def __init__(self, concat_dim, pred_dim1, pred_dim2, pred_dim3, out_dim, dropout):
        super(FClayer, self).__init__()
        self.dropout = dropout

        self.fc1 = Linear(concat_dim, pred_dim1)
        self.bn1 = BatchNorm1d(pred_dim1)
        self.fc2 = Linear(pred_dim1, pred_dim2)
        self.bn2 = BatchNorm1d(pred_dim2)
        self.fc3 = Linear(pred_dim2, pred_dim3)
        self.bn3 = BatchNorm1d(pred_dim3)
        self.fc4 = Linear(pred_dim3, out_dim)
    
    def forward(self, data):
        x = F.relu(self.fc1(data))
        x = F.dropout(self.bn1(x), p=self.dropout)
        x = F.relu(self.fc2(x))
        x = F.dropout(self.bn2(x), p=self.dropout)
        x = F.relu(self.fc3(x))
        x = F.dropout(self.bn3(x), p=self.dropout)
        x = self.fc4(x)
        return x
    
class Net(nn.Module):
    def __init__(self, args):
        super(Net, self).__init__()
        self.conv = GCNlayer(args.n_features, 
                              args.conv_dim1, 
                              args.conv_dim2, 
                              args.conv_dim3, 
                              args.concat_dim, 
                              args.dropout)
        self.fc = FClayer(args.concat_dim, 
                          args.pred_dim1, 
                          args.pred_dim2, 
                          args.pred_dim3, 
                          args.out_dim, 
                          args.dropout)
        
    def forward(self, data):
        x = self.conv(data)
        x = self.fc(x)
        x = F.log_softmax(x, dim=1)
        return x

# %%
class EarlyStopping:
    def __init__(self, patience=20, verbose=False, delta=0):
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.Inf
        self.delta = delta

    def __call__(self, val_loss, model):
        score = -val_loss
        if self.best_score is None:
            self.best_score = score
        elif score < self.best_score + self.delta:
            self.counter += 1
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.counter = 0

# %%
def train(model, device, optimizer, train_loader, criterion, args, prints):
    y_true = []
    y_pred = []
    epoch_loss = 0
    for i, data in enumerate(train_loader):
        data = data.to(device)
        labels = data.y.to(device)
        outputs = model(data)
        loss = criterion(outputs, labels)
        epoch_loss += loss
        optimizer.zero_grad()
        loss.backward()
        y_pred.extend(outputs.cpu().detach().max(axis=1).indices.tolist())
        y_true.extend(labels.cpu().detach().tolist())
    epoch_loss /= len(train_loader)
    return model, epoch_loss.tolist(), y_true, y_pred

def test(model, device, test_loader, criterion, args, prints):
    y_true = []
    y_pred = []
    epoch_loss = 0
    model.eval()
    with torch.no_grad():
        for i, data in enumerate(test_loader):
            data = data.to(device)
            labels = data.y.to(device)
            outputs = model(data)
            loss = criterion(outputs, labels)
            epoch_loss += loss
            y_pred.extend(outputs.cpu().detach().max(axis=1).indices.tolist())
            y_true.extend(labels.cpu().detach().tolist())
    epoch_loss /= len(train_loader)
    return model, epoch_loss.tolist(), y_true, y_pred

def results(true, pred):
    cm = confusion_matrix(true, pred)
    acc = accuracy_score(true, pred)
    micf1 = f1_score(true, pred, average='micro')
    macf1 = f1_score(true, pred, average='macro')
    print('Accuracy : %.2f' % acc)
    print('Micro F1 Score : %.2f' % micf1)
    print('Macro F1 Score : %.2f' % macf1)
    return cm, acc, micf1, macf1

def experiment(model, train_loader, test_loader, device, args, prints=True):
    
    optimizer = optim.Adam(model.parameters(),lr=args.lr)
    criterion = nn.CrossEntropyLoss()
    scheduler = optim.lr_scheduler.StepLR(optimizer,
                                          step_size=args.step_size,
                                          gamma=args.gamma)
    early_stopping = EarlyStopping(patience=args.patience, verbose=True)
    
    list_train_loss = []
    list_test_loss = []
    if prints:
        print('[Train]')
    for epoch in range(args.epoch):
        optimizer.step()
        scheduler.step()
        model, train_loss, _, _ = train(model, device, optimizer, train_loader, criterion, args, prints)
        model, test_loss, y_true, y_pred = test(model, device, test_loader, criterion, args, prints)
        list_train_loss.append(train_loss)
        list_test_loss.append(test_loss)
        if prints:
            print('- Epoch: %d\t- Train Loss: %.4f\t- Test Loss: %.4f' % (epoch+1, train_loss, test_loss))
        early_stopping(test_loss, model)
        if early_stopping.early_stop:
            print("Early stopping")
            break
    if prints:
        print('[Tets]')
    model, test_loss, y_true, y_pred = test(model, device, test_loader, criterion, args, prints)
    
    cm, acc, micf1, macf1 = results(y_true, y_pred)
    
    args.list_train_loss = list_train_loss
    args.list_test_loss = list_test_loss
    args.y_true = y_true
    args.y_pred = y_pred
    args.cm = cm
    args.acc = acc
    args.micf1 = micf1
    args.macf1 = macf1
    
    return args

# %%
def plot_result(result_df):
    
    figsize = 4
    label_fs = 14
    legend_fs = 12
    ticks_fs = 12

    train_loss = result_df['list_train_loss'].iloc[0]
    test_loss = result_df['list_test_loss'].iloc[0]
    y_true = result_df['y_true'].iloc[0]
    y_pred = result_df['y_pred'].iloc[0]
    classes = result_df['classes'].iloc[0]
    cm, acc, micf1, macf1 = results(y_true, y_pred)
    
    cm_matrix = pd.DataFrame(cm, 
                             index=classes, 
                             columns=classes)
    plt.figure(figsize=(figsize+1, figsize))
    sns.heatmap(cm_matrix.astype('int'), annot=True, cmap='Blues', fmt="d", 
               xticklabels=classes, yticklabels=classes, annot_kws={"size": 8})
    plt.tick_params(left=False, bottom=False)
    plt.xlabel('Predicted Class', fontsize=label_fs)
    plt.ylabel('True Class', fontsize=label_fs)
    plt.xticks(fontsize=ticks_fs)
    plt.yticks(fontsize=ticks_fs)
    plt.show()
    
    plt.figure(figsize=(figsize, figsize))
    plt.plot([e for e in range(len(train_loss))], [float(t) for t in train_loss], label="Train Loss", c='blue')
    plt.plot([e for e in range(len(train_loss))], [float(t) for t in test_loss], label="Test Loss", c='red')
    plt.xlabel("Epoch", fontsize=label_fs)
    plt.ylabel("Loss", fontsize=label_fs)
    plt.xticks(fontsize=ticks_fs)
    plt.yticks(fontsize=ticks_fs)
    plt.legend(fontsize=legend_fs)
    plt.show()
    
    return cm, acc, micf1, macf1

# %%
args.batch_size = 512
args.optim = 'Adam'
args.step_size = 10
args.gamma = 0.9
args.dropout = 0.2
args.lr = 0.0001
args.epoch = 3000
args.patience = 100
args.n_features = 27
conv_dim = 128
args.conv_dim1 = conv_dim
args.conv_dim2 = conv_dim
args.conv_dim3 = conv_dim
args.concat_dim = 128
args.pred_dim1 = 128
args.pred_dim2 = 64
args.pred_dim3 = 32
args.out_dim = len(classes)
args.classes = [k for k in classes.keys()]

model = Net(args)
model = model.to(device)

train_loader = DataLoader(train_X, batch_size=args.batch_size, shuffle=True, drop_last=False)
test_loader = DataLoader(test_X, batch_size=args.batch_size, shuffle=False, drop_last=False)

dict_result = dict()
args.exp_name = f'Exp'
result = vars(experiment(model, train_loader, test_loader, device, args, prints=True))
dict_result[args.exp_name] = copy.deepcopy(result)
torch.cuda.empty_cache()

result_df = pd.DataFrame(dict_result).transpose()
result_df.to_csv(f'./result.csv', index=False)
# Out:
# [Train]
# - Epoch: 1	- Train Loss: 2.1985	- Test Loss: 0.5667
# - Epoch: 2	- Train Loss: 2.1663	- Test Loss: 0.5569
# - Epoch: 3	- Train Loss: 2.1054	- Test Loss: 0.5408
# - Epoch: 4	- Train Loss: 2.0433	- Test Loss: 0.5263
# - Epoch: 5	- Train Loss: 1.9946	- Test Loss: 0.5157
# - Epoch: 6	- Train Loss: 1.9356	- Test Loss: 0.4994
# - Epoch: 7	- Train Loss: 1.8907	- Test Loss: 0.4891
# - Epoch: 8	- Train Loss: 1.8500	- Test Loss: 0.4791
# - Epoch: 9	- Train Loss: 1.8054	- Test Loss: 0.4687
# - Epoch: 10	- Train Loss: 1.7655	- Test Loss: 0.4565
# - Epoch: 11	- Train Loss: 1.7423	- Test Loss: 0.4525
# - Epoch: 12	- Train Loss: 1.7146	- Test Loss: 0.4439
# - Epoch: 13	- Train Loss: 1.6887	- Test Loss: 0.4405
# - Epoch: 14	- Train Loss: 1.6699	- Test Loss: 0.4345
# - Epoch: 15	- Train Loss: 1.6424	- Test Loss: 0.4263
# - Epoch: 16	- Train Loss: 1.6141	- Test Loss: 0.4182
# - Epoch: 17	- Train Loss: 1.5931	- Test Loss: 0.4172
# - Epoch: 18	- Train Loss: 1.5688	- Test Loss: 0.4059
# - Epoch: 19	- Train Loss: 1.5431	- Test Loss: 0.4000
# - Epoch: 20	- Train Loss: 1.5281	- Test Loss: 0.3957
# - Epoch: 21	- Train Loss: 1.5089	- Test Loss: 0.3952
# - Epoch: 22	- Train Loss: 1.4889	- Test Loss: 0.3877
# - Epoch: 23	- Train Loss: 1.4733	- Test Loss: 0.3827
# - Epoch: 24	- Train Loss: 1.4532	- Test Loss: 0.3807
# - Epoch: 25	- Train Loss: 1.4302	- Test Loss: 0.3722
# - Epoch: 26	- Train Loss: 1.4136	- Test Loss: 0.3706
# - Epoch: 27	- Train Loss: 1.3986	- Test Loss: 0.3634
# - Epoch: 28	- Train Loss: 1.3821	- Test Loss: 0.3594
# - Epoch: 29	- Train Loss: 1.3686	- Test Loss: 0.3580
# - Epoch: 30	- Train Loss: 1.3475	- Test Loss: 0.3539
# - Epoch: 31	- Train Loss: 1.3341	- Test Loss: 0.3490
# - Epoch: 32	- Train Loss: 1.3198	- Test Loss: 0.3442
# - Epoch: 33	- Train Loss: 1.3090	- Test Loss: 0.3393
# - Epoch: 34	- Train Loss: 1.2985	- Test Loss: 0.3398
# - Epoch: 35	- Train Loss: 1.2779	- Test Loss: 0.3325
# - Epoch: 36	- Train Loss: 1.2683	- Test Loss: 0.3286
# - Epoch: 37	- Train Loss: 1.2612	- Test Loss: 0.3276
# - Epoch: 38	- Train Loss: 1.2434	- Test Loss: 0.3285
# - Epoch: 39	- Train Loss: 1.2305	- Test Loss: 0.3225
# - Epoch: 40	- Train Loss: 1.2219	- Test Loss: 0.3192
# - Epoch: 41	- Train Loss: 1.2165	- Test Loss: 0.3177
# - Epoch: 42	- Train Loss: 1.2068	- Test Loss: 0.3145
# - Epoch: 43	- Train Loss: 1.1960	- Test Loss: 0.3113
# - Epoch: 44	- Train Loss: 1.1892	- Test Loss: 0.3116
# - Epoch: 45	- Train Loss: 1.1783	- Test Loss: 0.3067
# - Epoch: 46	- Train Loss: 1.1663	- Test Loss: 0.3024
# - Epoch: 47	- Train Loss: 1.1554	- Test Loss: 0.3036
# - Epoch: 48	- Train Loss: 1.1484	- Test Loss: 0.2984
# - Epoch: 49	- Train Loss: 1.1421	- Test Loss: 0.2998
# - Epoch: 50	- Train Loss: 1.1352	- Test Loss: 0.2977
# - Epoch: 51	- Train Loss: 1.1230	- Test Loss: 0.2943
# - Epoch: 52	- Train Loss: 1.1116	- Test Loss: 0.2937
# - Epoch: 53	- Train Loss: 1.1057	- Test Loss: 0.2892
# - Epoch: 54	- Train Loss: 1.1004	- Test Loss: 0.2882
# - Epoch: 55	- Train Loss: 1.0919	- Test Loss: 0.2843
# - Epoch: 56	- Train Loss: 1.0874	- Test Loss: 0.2827
# - Epoch: 57	- Train Loss: 1.0754	- Test Loss: 0.2809
# - Epoch: 58	- Train Loss: 1.0725	- Test Loss: 0.2838
# - Epoch: 59	- Train Loss: 1.0543	- Test Loss: 0.2782
# - Epoch: 60	- Train Loss: 1.0562	- Test Loss: 0.2784
# - Epoch: 61	- Train Loss: 1.0468	- Test Loss: 0.2749
# - Epoch: 62	- Train Loss: 1.0380	- Test Loss: 0.2732
# - Epoch: 63	- Train Loss: 1.0286	- Test Loss: 0.2718
# - Epoch: 64	- Train Loss: 1.0277	- Test Loss: 0.2699
# - Epoch: 65	- Train Loss: 1.0248	- Test Loss: 0.2711
# - Epoch: 66	- Train Loss: 1.0119	- Test Loss: 0.2648
# - Epoch: 67	- Train Loss: 1.0077	- Test Loss: 0.2651
# - Epoch: 68	- Train Loss: 0.9971	- Test Loss: 0.2628
# - Epoch: 69	- Train Loss: 0.9927	- Test Loss: 0.2630
# - Epoch: 70	- Train Loss: 0.9881	- Test Loss: 0.2604
# - Epoch: 71	- Train Loss: 0.9863	- Test Loss: 0.2588
# - Epoch: 72	- Train Loss: 0.9807	- Test Loss: 0.2596
# - Epoch: 73	- Train Loss: 0.9700	- Test Loss: 0.2565
# - Epoch: 74	- Train Loss: 0.9766	- Test Loss: 0.2559
# - Epoch: 75	- Train Loss: 0.9657	- Test Loss: 0.2529
# - Epoch: 76	- Train Loss: 0.9551	- Test Loss: 0.2502
# - Epoch: 77	- Train Loss: 0.9544	- Test Loss: 0.2530
# - Epoch: 78	- Train Loss: 0.9504	- Test Loss: 0.2496
# - Epoch: 79	- Train Loss: 0.9417	- Test Loss: 0.2498
# - Epoch: 80	- Train Loss: 0.9382	- Test Loss: 0.2492
# - Epoch: 81	- Train Loss: 0.9408	- Test Loss: 0.2469
# - Epoch: 82	- Train Loss: 0.9332	- Test Loss: 0.2471
# - Epoch: 83	- Train Loss: 0.9263	- Test Loss: 0.2444
# - Epoch: 84	- Train Loss: 0.9248	- Test Loss: 0.2443
# - Epoch: 85	- Train Loss: 0.9215	- Test Loss: 0.2401
# - Epoch: 86	- Train Loss: 0.9132	- Test Loss: 0.2413
# - Epoch: 87	- Train Loss: 0.9125	- Test Loss: 0.2391
# - Epoch: 88	- Train Loss: 0.9080	- Test Loss: 0.2396
# - Epoch: 89	- Train Loss: 0.8996	- Test Loss: 0.2351
# - Epoch: 90	- Train Loss: 0.8980	- Test Loss: 0.2372
# - Epoch: 91	- Train Loss: 0.8935	- Test Loss: 0.2358
# - Epoch: 92	- Train Loss: 0.8942	- Test Loss: 0.2353
# - Epoch: 93	- Train Loss: 0.8870	- Test Loss: 0.2337
# - Epoch: 94	- Train Loss: 0.8780	- Test Loss: 0.2329
# - Epoch: 95	- Train Loss: 0.8792	- Test Loss: 0.2322
# - Epoch: 96	- Train Loss: 0.8753	- Test Loss: 0.2319
# - Epoch: 97	- Train Loss: 0.8720	- Test Loss: 0.2287
# - Epoch: 98	- Train Loss: 0.8614	- Test Loss: 0.2259
# - Epoch: 99	- Train Loss: 0.8578	- Test Loss: 0.2293
# - Epoch: 100	- Train Loss: 0.8597	- Test Loss: 0.2268
# - Epoch: 101	- Train Loss: 0.8555	- Test Loss: 0.2267
# - Epoch: 102	- Train Loss: 0.8484	- Test Loss: 0.2248
# - Epoch: 103	- Train Loss: 0.8521	- Test Loss: 0.2234
# - Epoch: 104	- Train Loss: 0.8463	- Test Loss: 0.2249
# - Epoch: 105	- Train Loss: 0.8402	- Test Loss: 0.2239
# - Epoch: 106	- Train Loss: 0.8400	- Test Loss: 0.2229
# - Epoch: 107	- Train Loss: 0.8344	- Test Loss: 0.2209
# - Epoch: 108	- Train Loss: 0.8343	- Test Loss: 0.2187
# - Epoch: 109	- Train Loss: 0.8328	- Test Loss: 0.2189
# - Epoch: 110	- Train Loss: 0.8308	- Test Loss: 0.2175
# - Epoch: 111	- Train Loss: 0.8230	- Test Loss: 0.2165
# - Epoch: 112	- Train Loss: 0.8208	- Test Loss: 0.2199
# - Epoch: 113	- Train Loss: 0.8193	- Test Loss: 0.2158
# - Epoch: 114	- Train Loss: 0.8180	- Test Loss: 0.2144
# - Epoch: 115	- Train Loss: 0.8153	- Test Loss: 0.2140
# - Epoch: 116	- Train Loss: 0.8071	- Test Loss: 0.2178
# - Epoch: 117	- Train Loss: 0.8061	- Test Loss: 0.2167
# - Epoch: 118	- Train Loss: 0.8064	- Test Loss: 0.2142
# - Epoch: 119	- Train Loss: 0.8018	- Test Loss: 0.2115
# - Epoch: 120	- Train Loss: 0.7997	- Test Loss: 0.2110
# - Epoch: 121	- Train Loss: 0.7951	- Test Loss: 0.2105
# - Epoch: 122	- Train Loss: 0.7963	- Test Loss: 0.2113
# - Epoch: 123	- Train Loss: 0.7951	- Test Loss: 0.2070
# - Epoch: 124	- Train Loss: 0.7859	- Test Loss: 0.2086
# - Epoch: 125	- Train Loss: 0.7878	- Test Loss: 0.2112
# - Epoch: 126	- Train Loss: 0.7837	- Test Loss: 0.2088
# - Epoch: 127	- Train Loss: 0.7778	- Test Loss: 0.2055
# - Epoch: 128	- Train Loss: 0.7780	- Test Loss: 0.2052
# - Epoch: 129	- Train Loss: 0.7811	- Test Loss: 0.2071
# - Epoch: 130	- Train Loss: 0.7706	- Test Loss: 0.2044
# - Epoch: 131	- Train Loss: 0.7731	- Test Loss: 0.2059
# - Epoch: 132	- Train Loss: 0.7701	- Test Loss: 0.2046
# - Epoch: 133	- Train Loss: 0.7641	- Test Loss: 0.2065
# - Epoch: 134	- Train Loss: 0.7678	- Test Loss: 0.2024
# - Epoch: 135	- Train Loss: 0.7659	- Test Loss: 0.2035
# - Epoch: 136	- Train Loss: 0.7613	- Test Loss: 0.2025
# - Epoch: 137	- Train Loss: 0.7608	- Test Loss: 0.2018
# - Epoch: 138	- Train Loss: 0.7573	- Test Loss: 0.1991
# - Epoch: 139	- Train Loss: 0.7526	- Test Loss: 0.2023
# - Epoch: 140	- Train Loss: 0.7507	- Test Loss: 0.2038
# - Epoch: 141	- Train Loss: 0.7556	- Test Loss: 0.1989
# - Epoch: 142	- Train Loss: 0.7535	- Test Loss: 0.1959
# - Epoch: 143	- Train Loss: 0.7526	- Test Loss: 0.2015
# - Epoch: 144	- Train Loss: 0.7459	- Test Loss: 0.1986
# - Epoch: 145	- Train Loss: 0.7461	- Test Loss: 0.1980
# - Epoch: 146	- Train Loss: 0.7420	- Test Loss: 0.1998
# - Epoch: 147	- Train Loss: 0.7367	- Test Loss: 0.1975
# - Epoch: 148	- Train Loss: 0.7406	- Test Loss: 0.1979
# - Epoch: 149	- Train Loss: 0.7338	- Test Loss: 0.1946
# - Epoch: 150	- Train Loss: 0.7374	- Test Loss: 0.1942
# - Epoch: 151	- Train Loss: 0.7345	- Test Loss: 0.1975
# - Epoch: 152	- Train Loss: 0.7335	- Test Loss: 0.1936
# - Epoch: 153	- Train Loss: 0.7292	- Test Loss: 0.1944
# - Epoch: 154	- Train Loss: 0.7304	- Test Loss: 0.1975
# - Epoch: 155	- Train Loss: 0.7326	- Test Loss: 0.1933
# - Epoch: 156	- Train Loss: 0.7278	- Test Loss: 0.1921
# - Epoch: 157	- Train Loss: 0.7232	- Test Loss: 0.1970
# - Epoch: 158	- Train Loss: 0.7285	- Test Loss: 0.1935
# - Epoch: 159	- Train Loss: 0.7197	- Test Loss: 0.1935
# - Epoch: 160	- Train Loss: 0.7229	- Test Loss: 0.1931
# - Epoch: 161	- Train Loss: 0.7223	- Test Loss: 0.1916
# - Epoch: 162	- Train Loss: 0.7180	- Test Loss: 0.1915
# - Epoch: 163	- Train Loss: 0.7155	- Test Loss: 0.1891
# - Epoch: 164	- Train Loss: 0.7210	- Test Loss: 0.1917
# - Epoch: 165	- Train Loss: 0.7148	- Test Loss: 0.1907
# - Epoch: 166	- Train Loss: 0.7125	- Test Loss: 0.1891
# - Epoch: 167	- Train Loss: 0.7157	- Test Loss: 0.1916
# - Epoch: 168	- Train Loss: 0.7118	- Test Loss: 0.1873
# - Epoch: 169	- Train Loss: 0.7093	- Test Loss: 0.1879
# - Epoch: 170	- Train Loss: 0.7098	- Test Loss: 0.1892
# - Epoch: 171	- Train Loss: 0.7093	- Test Loss: 0.1848
# - Epoch: 172	- Train Loss: 0.7048	- Test Loss: 0.1884
# - Epoch: 173	- Train Loss: 0.7101	- Test Loss: 0.1876
# - Epoch: 174	- Train Loss: 0.7033	- Test Loss: 0.1863
# - Epoch: 175	- Train Loss: 0.6993	- Test Loss: 0.1857
# - Epoch: 176	- Train Loss: 0.6991	- Test Loss: 0.1854
# - Epoch: 177	- Train Loss: 0.6986	- Test Loss: 0.1848
# - Epoch: 178	- Train Loss: 0.7002	- Test Loss: 0.1851
# - Epoch: 179	- Train Loss: 0.6927	- Test Loss: 0.1839
# - Epoch: 180	- Train Loss: 0.6959	- Test Loss: 0.1845
# - Epoch: 181	- Train Loss: 0.6957	- Test Loss: 0.1890
# - Epoch: 182	- Train Loss: 0.6912	- Test Loss: 0.1845
# - Epoch: 183	- Train Loss: 0.6929	- Test Loss: 0.1822
# - Epoch: 184	- Train Loss: 0.6933	- Test Loss: 0.1859
# - Epoch: 185	- Train Loss: 0.6912	- Test Loss: 0.1847
# - Epoch: 186	- Train Loss: 0.6936	- Test Loss: 0.1844
# - Epoch: 187	- Train Loss: 0.6929	- Test Loss: 0.1821
# - Epoch: 188	- Train Loss: 0.6924	- Test Loss: 0.1809
# - Epoch: 189	- Train Loss: 0.6938	- Test Loss: 0.1827
# - Epoch: 190	- Train Loss: 0.6894	- Test Loss: 0.1820
# - Epoch: 191	- Train Loss: 0.6774	- Test Loss: 0.1828
# - Epoch: 192	- Train Loss: 0.6832	- Test Loss: 0.1833
# - Epoch: 193	- Train Loss: 0.6833	- Test Loss: 0.1826
# - Epoch: 194	- Train Loss: 0.6859	- Test Loss: 0.1794
# - Epoch: 195	- Train Loss: 0.6804	- Test Loss: 0.1809
# - Epoch: 196	- Train Loss: 0.6831	- Test Loss: 0.1818
# - Epoch: 197	- Train Loss: 0.6768	- Test Loss: 0.1805
# - Epoch: 198	- Train Loss: 0.6768	- Test Loss: 0.1812
# - Epoch: 199	- Train Loss: 0.6742	- Test Loss: 0.1824
# - Epoch: 200	- Train Loss: 0.6725	- Test Loss: 0.1809
# - Epoch: 201	- Train Loss: 0.6758	- Test Loss: 0.1816
# - Epoch: 202	- Train Loss: 0.6746	- Test Loss: 0.1793
# - Epoch: 203	- Train Loss: 0.6776	- Test Loss: 0.1793
# - Epoch: 204	- Train Loss: 0.6777	- Test Loss: 0.1821
# - Epoch: 205	- Train Loss: 0.6710	- Test Loss: 0.1776
# - Epoch: 206	- Train Loss: 0.6712	- Test Loss: 0.1794
# - Epoch: 207	- Train Loss: 0.6732	- Test Loss: 0.1775
# - Epoch: 208	- Train Loss: 0.6685	- Test Loss: 0.1794
# - Epoch: 209	- Train Loss: 0.6664	- Test Loss: 0.1801
# - Epoch: 210	- Train Loss: 0.6686	- Test Loss: 0.1808
# - Epoch: 211	- Train Loss: 0.6627	- Test Loss: 0.1779
# - Epoch: 212	- Train Loss: 0.6676	- Test Loss: 0.1776
# - Epoch: 213	- Train Loss: 0.6717	- Test Loss: 0.1777
# - Epoch: 214	- Train Loss: 0.6607	- Test Loss: 0.1780
# - Epoch: 215	- Train Loss: 0.6679	- Test Loss: 0.1765
# - Epoch: 216	- Train Loss: 0.6670	- Test Loss: 0.1776
# - Epoch: 217	- Train Loss: 0.6687	- Test Loss: 0.1758
# - Epoch: 218	- Train Loss: 0.6619	- Test Loss: 0.1781
# - Epoch: 219	- Train Loss: 0.6577	- Test Loss: 0.1761
# - Epoch: 220	- Train Loss: 0.6644	- Test Loss: 0.1778
# - Epoch: 221	- Train Loss: 0.6643	- Test Loss: 0.1774
# - Epoch: 222	- Train Loss: 0.6582	- Test Loss: 0.1763
# - Epoch: 223	- Train Loss: 0.6622	- Test Loss: 0.1771
# - Epoch: 224	- Train Loss: 0.6610	- Test Loss: 0.1780
# - Epoch: 225	- Train Loss: 0.6586	- Test Loss: 0.1770
# - Epoch: 226	- Train Loss: 0.6580	- Test Loss: 0.1769
# - Epoch: 227	- Train Loss: 0.6568	- Test Loss: 0.1756
# - Epoch: 228	- Train Loss: 0.6574	- Test Loss: 0.1743
# - Epoch: 229	- Train Loss: 0.6538	- Test Loss: 0.1759
# - Epoch: 230	- Train Loss: 0.6550	- Test Loss: 0.1741
# - Epoch: 231	- Train Loss: 0.6535	- Test Loss: 0.1758
# - Epoch: 232	- Train Loss: 0.6558	- Test Loss: 0.1754
# - Epoch: 233	- Train Loss: 0.6582	- Test Loss: 0.1763
# - Epoch: 234	- Train Loss: 0.6560	- Test Loss: 0.1758
# - Epoch: 235	- Train Loss: 0.6530	- Test Loss: 0.1741
# - Epoch: 236	- Train Loss: 0.6570	- Test Loss: 0.1742
# - Epoch: 237	- Train Loss: 0.6545	- Test Loss: 0.1742
# - Epoch: 238	- Train Loss: 0.6534	- Test Loss: 0.1748
# - Epoch: 239	- Train Loss: 0.6527	- Test Loss: 0.1740
# - Epoch: 240	- Train Loss: 0.6526	- Test Loss: 0.1739
# - Epoch: 241	- Train Loss: 0.6508	- Test Loss: 0.1719
# - Epoch: 242	- Train Loss: 0.6522	- Test Loss: 0.1733
# - Epoch: 243	- Train Loss: 0.6462	- Test Loss: 0.1761
# - Epoch: 244	- Train Loss: 0.6446	- Test Loss: 0.1735
# - Epoch: 245	- Train Loss: 0.6456	- Test Loss: 0.1722
# - Epoch: 246	- Train Loss: 0.6501	- Test Loss: 0.1738
# - Epoch: 247	- Train Loss: 0.6447	- Test Loss: 0.1733
# - Epoch: 248	- Train Loss: 0.6415	- Test Loss: 0.1736
# - Epoch: 249	- Train Loss: 0.6469	- Test Loss: 0.1741
# - Epoch: 250	- Train Loss: 0.6450	- Test Loss: 0.1727
# - Epoch: 251	- Train Loss: 0.6464	- Test Loss: 0.1738
# - Epoch: 252	- Train Loss: 0.6442	- Test Loss: 0.1713
# - Epoch: 253	- Train Loss: 0.6448	- Test Loss: 0.1734
# - Epoch: 254	- Train Loss: 0.6446	- Test Loss: 0.1728
# - Epoch: 255	- Train Loss: 0.6464	- Test Loss: 0.1735
# - Epoch: 256	- Train Loss: 0.6431	- Test Loss: 0.1727
# - Epoch: 257	- Train Loss: 0.6402	- Test Loss: 0.1721
# - Epoch: 258	- Train Loss: 0.6443	- Test Loss: 0.1713
# - Epoch: 259	- Train Loss: 0.6427	- Test Loss: 0.1712
# - Epoch: 260	- Train Loss: 0.6404	- Test Loss: 0.1728
# - Epoch: 261	- Train Loss: 0.6433	- Test Loss: 0.1747
# - Epoch: 262	- Train Loss: 0.6373	- Test Loss: 0.1706
# - Epoch: 263	- Train Loss: 0.6403	- Test Loss: 0.1749
# - Epoch: 264	- Train Loss: 0.6419	- Test Loss: 0.1717
# - Epoch: 265	- Train Loss: 0.6422	- Test Loss: 0.1715
# - Epoch: 266	- Train Loss: 0.6336	- Test Loss: 0.1721
# - Epoch: 267	- Train Loss: 0.6442	- Test Loss: 0.1732
# - Epoch: 268	- Train Loss: 0.6401	- Test Loss: 0.1715
# - Epoch: 269	- Train Loss: 0.6403	- Test Loss: 0.1686
# - Epoch: 270	- Train Loss: 0.6366	- Test Loss: 0.1692
# - Epoch: 271	- Train Loss: 0.6329	- Test Loss: 0.1721
# - Epoch: 272	- Train Loss: 0.6376	- Test Loss: 0.1695
# - Epoch: 273	- Train Loss: 0.6308	- Test Loss: 0.1691
# - Epoch: 274	- Train Loss: 0.6383	- Test Loss: 0.1732
# - Epoch: 275	- Train Loss: 0.6406	- Test Loss: 0.1734
# - Epoch: 276	- Train Loss: 0.6370	- Test Loss: 0.1702
# - Epoch: 277	- Train Loss: 0.6311	- Test Loss: 0.1724
# - Epoch: 278	- Train Loss: 0.6301	- Test Loss: 0.1700
# - Epoch: 279	- Train Loss: 0.6352	- Test Loss: 0.1662
# - Epoch: 280	- Train Loss: 0.6344	- Test Loss: 0.1677
# - Epoch: 281	- Train Loss: 0.6341	- Test Loss: 0.1718
# - Epoch: 282	- Train Loss: 0.6352	- Test Loss: 0.1712
# - Epoch: 283	- Train Loss: 0.6342	- Test Loss: 0.1700
# - Epoch: 284	- Train Loss: 0.6349	- Test Loss: 0.1690
# - Epoch: 285	- Train Loss: 0.6349	- Test Loss: 0.1681
# - Epoch: 286	- Train Loss: 0.6353	- Test Loss: 0.1669
# - Epoch: 287	- Train Loss: 0.6339	- Test Loss: 0.1724
# - Epoch: 288	- Train Loss: 0.6312	- Test Loss: 0.1665
# - Epoch: 289	- Train Loss: 0.6293	- Test Loss: 0.1707
# - Epoch: 290	- Train Loss: 0.6330	- Test Loss: 0.1673
# - Epoch: 291	- Train Loss: 0.6321	- Test Loss: 0.1689
# - Epoch: 292	- Train Loss: 0.6317	- Test Loss: 0.1696
# - Epoch: 293	- Train Loss: 0.6317	- Test Loss: 0.1683
# - Epoch: 294	- Train Loss: 0.6312	- Test Loss: 0.1666
# - Epoch: 295	- Train Loss: 0.6335	- Test Loss: 0.1695
# - Epoch: 296	- Train Loss: 0.6336	- Test Loss: 0.1700
# - Epoch: 297	- Train Loss: 0.6301	- Test Loss: 0.1684
# - Epoch: 298	- Train Loss: 0.6334	- Test Loss: 0.1688
# - Epoch: 299	- Train Loss: 0.6282	- Test Loss: 0.1653
# - Epoch: 300	- Train Loss: 0.6292	- Test Loss: 0.1679
# - Epoch: 301	- Train Loss: 0.6316	- Test Loss: 0.1672
# - Epoch: 302	- Train Loss: 0.6305	- Test Loss: 0.1666
# - Epoch: 303	- Train Loss: 0.6290	- Test Loss: 0.1673
# - Epoch: 304	- Train Loss: 0.6273	- Test Loss: 0.1698
# - Epoch: 305	- Train Loss: 0.6273	- Test Loss: 0.1679
# - Epoch: 306	- Train Loss: 0.6289	- Test Loss: 0.1668
# - Epoch: 307	- Train Loss: 0.6294	- Test Loss: 0.1660
# - Epoch: 308	- Train Loss: 0.6311	- Test Loss: 0.1684
# - Epoch: 309	- Train Loss: 0.6323	- Test Loss: 0.1696
# - Epoch: 310	- Train Loss: 0.6246	- Test Loss: 0.1663
# - Epoch: 311	- Train Loss: 0.6253	- Test Loss: 0.1690
# - Epoch: 312	- Train Loss: 0.6256	- Test Loss: 0.1686
# - Epoch: 313	- Train Loss: 0.6272	- Test Loss: 0.1672
# - Epoch: 314	- Train Loss: 0.6246	- Test Loss: 0.1675
# - Epoch: 315	- Train Loss: 0.6247	- Test Loss: 0.1662
# - Epoch: 316	- Train Loss: 0.6265	- Test Loss: 0.1678
# - Epoch: 317	- Train Loss: 0.6248	- Test Loss: 0.1669
# - Epoch: 318	- Train Loss: 0.6267	- Test Loss: 0.1672
# - Epoch: 319	- Train Loss: 0.6277	- Test Loss: 0.1655
# - Epoch: 320	- Train Loss: 0.6235	- Test Loss: 0.1646
# - Epoch: 321	- Train Loss: 0.6226	- Test Loss: 0.1688
# - Epoch: 322	- Train Loss: 0.6215	- Test Loss: 0.1666
# - Epoch: 323	- Train Loss: 0.6199	- Test Loss: 0.1697
# - Epoch: 324	- Train Loss: 0.6290	- Test Loss: 0.1668
# - Epoch: 325	- Train Loss: 0.6271	- Test Loss: 0.1678
# - Epoch: 326	- Train Loss: 0.6241	- Test Loss: 0.1684
# - Epoch: 327	- Train Loss: 0.6277	- Test Loss: 0.1658
# - Epoch: 328	- Train Loss: 0.6244	- Test Loss: 0.1672
# - Epoch: 329	- Train Loss: 0.6251	- Test Loss: 0.1647
# - Epoch: 330	- Train Loss: 0.6216	- Test Loss: 0.1661
# - Epoch: 331	- Train Loss: 0.6223	- Test Loss: 0.1646
# - Epoch: 332	- Train Loss: 0.6239	- Test Loss: 0.1685
# - Epoch: 333	- Train Loss: 0.6163	- Test Loss: 0.1662
# - Epoch: 334	- Train Loss: 0.6234	- Test Loss: 0.1661
# - Epoch: 335	- Train Loss: 0.6226	- Test Loss: 0.1690
# - Epoch: 336	- Train Loss: 0.6246	- Test Loss: 0.1669
# - Epoch: 337	- Train Loss: 0.6230	- Test Loss: 0.1670
# - Epoch: 338	- Train Loss: 0.6173	- Test Loss: 0.1652
# - Epoch: 339	- Train Loss: 0.6199	- Test Loss: 0.1653
# - Epoch: 340	- Train Loss: 0.6200	- Test Loss: 0.1684
# - Epoch: 341	- Train Loss: 0.6254	- Test Loss: 0.1667
# - Epoch: 342	- Train Loss: 0.6202	- Test Loss: 0.1662
# - Epoch: 343	- Train Loss: 0.6171	- Test Loss: 0.1651
# - Epoch: 344	- Train Loss: 0.6209	- Test Loss: 0.1643
# - Epoch: 345	- Train Loss: 0.6193	- Test Loss: 0.1644
# - Epoch: 346	- Train Loss: 0.6218	- Test Loss: 0.1656
# - Epoch: 347	- Train Loss: 0.6141	- Test Loss: 0.1673
# - Epoch: 348	- Train Loss: 0.6205	- Test Loss: 0.1663
# - Epoch: 349	- Train Loss: 0.6195	- Test Loss: 0.1652
# - Epoch: 350	- Train Loss: 0.6219	- Test Loss: 0.1664
# - Epoch: 351	- Train Loss: 0.6206	- Test Loss: 0.1647
# - Epoch: 352	- Train Loss: 0.6192	- Test Loss: 0.1640
# - Epoch: 353	- Train Loss: 0.6225	- Test Loss: 0.1652
# - Epoch: 354	- Train Loss: 0.6168	- Test Loss: 0.1633
# - Epoch: 355	- Train Loss: 0.6187	- Test Loss: 0.1693
# - Epoch: 356	- Train Loss: 0.6202	- Test Loss: 0.1626
# - Epoch: 357	- Train Loss: 0.6163	- Test Loss: 0.1659
# - Epoch: 358	- Train Loss: 0.6189	- Test Loss: 0.1634
# - Epoch: 359	- Train Loss: 0.6158	- Test Loss: 0.1662
# - Epoch: 360	- Train Loss: 0.6119	- Test Loss: 0.1658
# - Epoch: 361	- Train Loss: 0.6202	- Test Loss: 0.1651
# - Epoch: 362	- Train Loss: 0.6175	- Test Loss: 0.1645
# - Epoch: 363	- Train Loss: 0.6145	- Test Loss: 0.1632
# - Epoch: 364	- Train Loss: 0.6195	- Test Loss: 0.1649
# - Epoch: 365	- Train Loss: 0.6211	- Test Loss: 0.1655
# - Epoch: 366	- Train Loss: 0.6173	- Test Loss: 0.1656
# - Epoch: 367	- Train Loss: 0.6191	- Test Loss: 0.1639
# - Epoch: 368	- Train Loss: 0.6151	- Test Loss: 0.1637
# - Epoch: 369	- Train Loss: 0.6144	- Test Loss: 0.1677
# - Epoch: 370	- Train Loss: 0.6186	- Test Loss: 0.1647
# - Epoch: 371	- Train Loss: 0.6187	- Test Loss: 0.1664
# - Epoch: 372	- Train Loss: 0.6176	- Test Loss: 0.1635
# - Epoch: 373	- Train Loss: 0.6154	- Test Loss: 0.1665
# - Epoch: 374	- Train Loss: 0.6152	- Test Loss: 0.1638
# - Epoch: 375	- Train Loss: 0.6164	- Test Loss: 0.1662
# - Epoch: 376	- Train Loss: 0.6162	- Test Loss: 0.1657
# - Epoch: 377	- Train Loss: 0.6160	- Test Loss: 0.1644
# - Epoch: 378	- Train Loss: 0.6161	- Test Loss: 0.1668
# - Epoch: 379	- Train Loss: 0.6185	- Test Loss: 0.1639
# - Epoch: 380	- Train Loss: 0.6164	- Test Loss: 0.1641
# - Epoch: 381	- Train Loss: 0.6126	- Test Loss: 0.1689
# - Epoch: 382	- Train Loss: 0.6120	- Test Loss: 0.1640
# - Epoch: 383	- Train Loss: 0.6213	- Test Loss: 0.1617
# - Epoch: 384	- Train Loss: 0.6118	- Test Loss: 0.1619
# - Epoch: 385	- Train Loss: 0.6165	- Test Loss: 0.1665
# - Epoch: 386	- Train Loss: 0.6144	- Test Loss: 0.1669
# - Epoch: 387	- Train Loss: 0.6173	- Test Loss: 0.1645
# - Epoch: 388	- Train Loss: 0.6193	- Test Loss: 0.1649
# - Epoch: 389	- Train Loss: 0.6128	- Test Loss: 0.1627
# - Epoch: 390	- Train Loss: 0.6156	- Test Loss: 0.1656
# - Epoch: 391	- Train Loss: 0.6154	- Test Loss: 0.1627
# - Epoch: 392	- Train Loss: 0.6116	- Test Loss: 0.1654
# - Epoch: 393	- Train Loss: 0.6099	- Test Loss: 0.1667
# - Epoch: 394	- Train Loss: 0.6105	- Test Loss: 0.1645
# - Epoch: 395	- Train Loss: 0.6146	- Test Loss: 0.1633
# - Epoch: 396	- Train Loss: 0.6165	- Test Loss: 0.1634
# - Epoch: 397	- Train Loss: 0.6137	- Test Loss: 0.1636
# - Epoch: 398	- Train Loss: 0.6130	- Test Loss: 0.1654
# - Epoch: 399	- Train Loss: 0.6141	- Test Loss: 0.1647
# - Epoch: 400	- Train Loss: 0.6159	- Test Loss: 0.1639
# - Epoch: 401	- Train Loss: 0.6126	- Test Loss: 0.1637
# - Epoch: 402	- Train Loss: 0.6123	- Test Loss: 0.1638
# - Epoch: 403	- Train Loss: 0.6106	- Test Loss: 0.1626
# - Epoch: 404	- Train Loss: 0.6129	- Test Loss: 0.1668
# - Epoch: 405	- Train Loss: 0.6119	- Test Loss: 0.1658
# - Epoch: 406	- Train Loss: 0.6145	- Test Loss: 0.1684
# - Epoch: 407	- Train Loss: 0.6141	- Test Loss: 0.1646
# - Epoch: 408	- Train Loss: 0.6133	- Test Loss: 0.1647
# - Epoch: 409	- Train Loss: 0.6104	- Test Loss: 0.1651
# - Epoch: 410	- Train Loss: 0.6108	- Test Loss: 0.1641
# - Epoch: 411	- Train Loss: 0.6122	- Test Loss: 0.1639
# - Epoch: 412	- Train Loss: 0.6164	- Test Loss: 0.1661
# - Epoch: 413	- Train Loss: 0.6122	- Test Loss: 0.1643
# - Epoch: 414	- Train Loss: 0.6147	- Test Loss: 0.1648
# - Epoch: 415	- Train Loss: 0.6092	- Test Loss: 0.1648
# - Epoch: 416	- Train Loss: 0.6138	- Test Loss: 0.1653
# - Epoch: 417	- Train Loss: 0.6109	- Test Loss: 0.1630
# - Epoch: 418	- Train Loss: 0.6119	- Test Loss: 0.1620
# - Epoch: 419	- Train Loss: 0.6119	- Test Loss: 0.1642
# - Epoch: 420	- Train Loss: 0.6087	- Test Loss: 0.1663
# - Epoch: 421	- Train Loss: 0.6135	- Test Loss: 0.1621
# - Epoch: 422	- Train Loss: 0.6051	- Test Loss: 0.1627
# - Epoch: 423	- Train Loss: 0.6163	- Test Loss: 0.1669
# - Epoch: 424	- Train Loss: 0.6151	- Test Loss: 0.1639
# - Epoch: 425	- Train Loss: 0.6112	- Test Loss: 0.1641
# - Epoch: 426	- Train Loss: 0.6118	- Test Loss: 0.1648
# - Epoch: 427	- Train Loss: 0.6077	- Test Loss: 0.1649
# - Epoch: 428	- Train Loss: 0.6139	- Test Loss: 0.1646
# - Epoch: 429	- Train Loss: 0.6100	- Test Loss: 0.1629
# - Epoch: 430	- Train Loss: 0.6101	- Test Loss: 0.1643
# - Epoch: 431	- Train Loss: 0.6145	- Test Loss: 0.1662
# - Epoch: 432	- Train Loss: 0.6111	- Test Loss: 0.1629
# - Epoch: 433	- Train Loss: 0.6080	- Test Loss: 0.1622
# - Epoch: 434	- Train Loss: 0.6150	- Test Loss: 0.1633
# - Epoch: 435	- Train Loss: 0.6120	- Test Loss: 0.1640
# - Epoch: 436	- Train Loss: 0.6090	- Test Loss: 0.1644
# - Epoch: 437	- Train Loss: 0.6062	- Test Loss: 0.1620
# - Epoch: 438	- Train Loss: 0.6143	- Test Loss: 0.1627
# - Epoch: 439	- Train Loss: 0.6095	- Test Loss: 0.1649
# - Epoch: 440	- Train Loss: 0.6076	- Test Loss: 0.1649
# - Epoch: 441	- Train Loss: 0.6148	- Test Loss: 0.1641
# - Epoch: 442	- Train Loss: 0.6153	- Test Loss: 0.1635
# - Epoch: 443	- Train Loss: 0.6131	- Test Loss: 0.1610
# - Epoch: 444	- Train Loss: 0.6092	- Test Loss: 0.1640
# - Epoch: 445	- Train Loss: 0.6091	- Test Loss: 0.1626
# - Epoch: 446	- Train Loss: 0.6124	- Test Loss: 0.1634
# - Epoch: 447	- Train Loss: 0.6053	- Test Loss: 0.1644
# - Epoch: 448	- Train Loss: 0.6142	- Test Loss: 0.1638
# - Epoch: 449	- Train Loss: 0.6101	- Test Loss: 0.1628
# - Epoch: 450	- Train Loss: 0.6121	- Test Loss: 0.1608
# - Epoch: 451	- Train Loss: 0.6079	- Test Loss: 0.1633
# - Epoch: 452	- Train Loss: 0.6109	- Test Loss: 0.1626
# - Epoch: 453	- Train Loss: 0.6102	- Test Loss: 0.1644
# - Epoch: 454	- Train Loss: 0.6115	- Test Loss: 0.1633
# - Epoch: 455	- Train Loss: 0.6130	- Test Loss: 0.1631
# - Epoch: 456	- Train Loss: 0.6085	- Test Loss: 0.1643
# - Epoch: 457	- Train Loss: 0.6085	- Test Loss: 0.1617
# - Epoch: 458	- Train Loss: 0.6119	- Test Loss: 0.1624
# - Epoch: 459	- Train Loss: 0.6056	- Test Loss: 0.1631
# - Epoch: 460	- Train Loss: 0.6117	- Test Loss: 0.1633
# - Epoch: 461	- Train Loss: 0.6044	- Test Loss: 0.1628
# - Epoch: 462	- Train Loss: 0.6086	- Test Loss: 0.1617
# - Epoch: 463	- Train Loss: 0.6102	- Test Loss: 0.1638
# - Epoch: 464	- Train Loss: 0.6094	- Test Loss: 0.1610
# - Epoch: 465	- Train Loss: 0.6115	- Test Loss: 0.1623
# - Epoch: 466	- Train Loss: 0.6051	- Test Loss: 0.1605
# - Epoch: 467	- Train Loss: 0.6071	- Test Loss: 0.1663
# - Epoch: 468	- Train Loss: 0.6110	- Test Loss: 0.1625
# - Epoch: 469	- Train Loss: 0.6039	- Test Loss: 0.1615
# - Epoch: 470	- Train Loss: 0.6087	- Test Loss: 0.1620
# - Epoch: 471	- Train Loss: 0.6102	- Test Loss: 0.1628
# - Epoch: 472	- Train Loss: 0.6107	- Test Loss: 0.1613
# - Epoch: 473	- Train Loss: 0.6141	- Test Loss: 0.1656
# - Epoch: 474	- Train Loss: 0.6058	- Test Loss: 0.1624
# - Epoch: 475	- Train Loss: 0.6087	- Test Loss: 0.1653
# - Epoch: 476	- Train Loss: 0.6054	- Test Loss: 0.1613
# - Epoch: 477	- Train Loss: 0.6081	- Test Loss: 0.1604
# - Epoch: 478	- Train Loss: 0.6112	- Test Loss: 0.1630
# - Epoch: 479	- Train Loss: 0.6039	- Test Loss: 0.1626
# - Epoch: 480	- Train Loss: 0.6099	- Test Loss: 0.1652
# - Epoch: 481	- Train Loss: 0.6077	- Test Loss: 0.1591
# - Epoch: 482	- Train Loss: 0.6092	- Test Loss: 0.1633
# - Epoch: 483	- Train Loss: 0.6095	- Test Loss: 0.1612
# - Epoch: 484	- Train Loss: 0.6069	- Test Loss: 0.1632
# - Epoch: 485	- Train Loss: 0.6057	- Test Loss: 0.1637
# - Epoch: 486	- Train Loss: 0.6094	- Test Loss: 0.1619
# - Epoch: 487	- Train Loss: 0.6101	- Test Loss: 0.1616
# - Epoch: 488	- Train Loss: 0.6049	- Test Loss: 0.1668
# - Epoch: 489	- Train Loss: 0.6123	- Test Loss: 0.1638
# - Epoch: 490	- Train Loss: 0.6099	- Test Loss: 0.1613
# - Epoch: 491	- Train Loss: 0.6061	- Test Loss: 0.1634
# - Epoch: 492	- Train Loss: 0.6066	- Test Loss: 0.1625
# - Epoch: 493	- Train Loss: 0.6116	- Test Loss: 0.1620
# - Epoch: 494	- Train Loss: 0.6108	- Test Loss: 0.1618
# - Epoch: 495	- Train Loss: 0.6129	- Test Loss: 0.1623
# - Epoch: 496	- Train Loss: 0.6134	- Test Loss: 0.1614
# - Epoch: 497	- Train Loss: 0.6111	- Test Loss: 0.1626
# - Epoch: 498	- Train Loss: 0.6057	- Test Loss: 0.1620
# - Epoch: 499	- Train Loss: 0.6074	- Test Loss: 0.1643
# - Epoch: 500	- Train Loss: 0.6097	- Test Loss: 0.1590
# - Epoch: 501	- Train Loss: 0.6077	- Test Loss: 0.1636
# - Epoch: 502	- Train Loss: 0.6064	- Test Loss: 0.1635
# - Epoch: 503	- Train Loss: 0.6080	- Test Loss: 0.1635
# - Epoch: 504	- Train Loss: 0.6078	- Test Loss: 0.1647
# - Epoch: 505	- Train Loss: 0.6060	- Test Loss: 0.1628
# - Epoch: 506	- Train Loss: 0.6060	- Test Loss: 0.1606
# - Epoch: 507	- Train Loss: 0.6074	- Test Loss: 0.1675
# - Epoch: 508	- Train Loss: 0.6057	- Test Loss: 0.1659
# - Epoch: 509	- Train Loss: 0.6083	- Test Loss: 0.1614
# - Epoch: 510	- Train Loss: 0.6049	- Test Loss: 0.1653
# - Epoch: 511	- Train Loss: 0.6039	- Test Loss: 0.1613
# - Epoch: 512	- Train Loss: 0.6038	- Test Loss: 0.1648
# - Epoch: 513	- Train Loss: 0.6066	- Test Loss: 0.1638
# - Epoch: 514	- Train Loss: 0.6075	- Test Loss: 0.1616
# - Epoch: 515	- Train Loss: 0.6087	- Test Loss: 0.1645
# - Epoch: 516	- Train Loss: 0.6103	- Test Loss: 0.1611
# - Epoch: 517	- Train Loss: 0.6076	- Test Loss: 0.1636
# - Epoch: 518	- Train Loss: 0.6063	- Test Loss: 0.1641
# - Epoch: 519	- Train Loss: 0.6056	- Test Loss: 0.1618
# - Epoch: 520	- Train Loss: 0.6107	- Test Loss: 0.1615
# - Epoch: 521	- Train Loss: 0.6129	- Test Loss: 0.1648
# - Epoch: 522	- Train Loss: 0.6040	- Test Loss: 0.1641
# - Epoch: 523	- Train Loss: 0.6077	- Test Loss: 0.1622
# - Epoch: 524	- Train Loss: 0.6060	- Test Loss: 0.1619
# - Epoch: 525	- Train Loss: 0.6090	- Test Loss: 0.1609
# - Epoch: 526	- Train Loss: 0.6112	- Test Loss: 0.1602
# - Epoch: 527	- Train Loss: 0.6081	- Test Loss: 0.1635
# - Epoch: 528	- Train Loss: 0.6068	- Test Loss: 0.1632
# - Epoch: 529	- Train Loss: 0.6120	- Test Loss: 0.1610
# - Epoch: 530	- Train Loss: 0.6054	- Test Loss: 0.1642
# - Epoch: 531	- Train Loss: 0.6088	- Test Loss: 0.1636
# - Epoch: 532	- Train Loss: 0.6080	- Test Loss: 0.1625
# - Epoch: 533	- Train Loss: 0.6105	- Test Loss: 0.1624
# - Epoch: 534	- Train Loss: 0.6050	- Test Loss: 0.1613
# - Epoch: 535	- Train Loss: 0.6090	- Test Loss: 0.1625
# - Epoch: 536	- Train Loss: 0.6116	- Test Loss: 0.1607
# - Epoch: 537	- Train Loss: 0.6098	- Test Loss: 0.1610
# - Epoch: 538	- Train Loss: 0.6096	- Test Loss: 0.1598
# - Epoch: 539	- Train Loss: 0.6094	- Test Loss: 0.1596
# - Epoch: 540	- Train Loss: 0.6093	- Test Loss: 0.1636
# - Epoch: 541	- Train Loss: 0.6067	- Test Loss: 0.1622
# - Epoch: 542	- Train Loss: 0.6055	- Test Loss: 0.1604
# - Epoch: 543	- Train Loss: 0.6073	- Test Loss: 0.1608
# - Epoch: 544	- Train Loss: 0.6058	- Test Loss: 0.1600
# - Epoch: 545	- Train Loss: 0.6065	- Test Loss: 0.1618
# - Epoch: 546	- Train Loss: 0.6114	- Test Loss: 0.1630
# - Epoch: 547	- Train Loss: 0.6043	- Test Loss: 0.1620
# - Epoch: 548	- Train Loss: 0.6102	- Test Loss: 0.1625
# - Epoch: 549	- Train Loss: 0.6096	- Test Loss: 0.1615
# - Epoch: 550	- Train Loss: 0.6034	- Test Loss: 0.1596
# - Epoch: 551	- Train Loss: 0.6067	- Test Loss: 0.1658
# - Epoch: 552	- Train Loss: 0.6105	- Test Loss: 0.1638
# - Epoch: 553	- Train Loss: 0.6058	- Test Loss: 0.1620
# - Epoch: 554	- Train Loss: 0.6082	- Test Loss: 0.1616
# - Epoch: 555	- Train Loss: 0.6065	- Test Loss: 0.1638
# - Epoch: 556	- Train Loss: 0.6000	- Test Loss: 0.1636
# - Epoch: 557	- Train Loss: 0.6076	- Test Loss: 0.1622
# - Epoch: 558	- Train Loss: 0.6056	- Test Loss: 0.1622
# - Epoch: 559	- Train Loss: 0.6039	- Test Loss: 0.1622
# - Epoch: 560	- Train Loss: 0.6069	- Test Loss: 0.1594
# - Epoch: 561	- Train Loss: 0.6031	- Test Loss: 0.1619
# - Epoch: 562	- Train Loss: 0.6040	- Test Loss: 0.1619
# - Epoch: 563	- Train Loss: 0.6059	- Test Loss: 0.1629
# - Epoch: 564	- Train Loss: 0.6048	- Test Loss: 0.1624
# - Epoch: 565	- Train Loss: 0.6081	- Test Loss: 0.1616
# - Epoch: 566	- Train Loss: 0.6039	- Test Loss: 0.1614
# - Epoch: 567	- Train Loss: 0.6049	- Test Loss: 0.1659
# - Epoch: 568	- Train Loss: 0.6043	- Test Loss: 0.1623
# - Epoch: 569	- Train Loss: 0.6027	- Test Loss: 0.1617
# - Epoch: 570	- Train Loss: 0.6035	- Test Loss: 0.1644
# - Epoch: 571	- Train Loss: 0.6047	- Test Loss: 0.1603
# - Epoch: 572	- Train Loss: 0.6044	- Test Loss: 0.1621
# - Epoch: 573	- Train Loss: 0.6065	- Test Loss: 0.1631
# - Epoch: 574	- Train Loss: 0.6084	- Test Loss: 0.1614
# - Epoch: 575	- Train Loss: 0.6064	- Test Loss: 0.1641
# - Epoch: 576	- Train Loss: 0.6108	- Test Loss: 0.1600
# - Epoch: 577	- Train Loss: 0.6079	- Test Loss: 0.1642
# - Epoch: 578	- Train Loss: 0.6089	- Test Loss: 0.1607
# - Epoch: 579	- Train Loss: 0.6080	- Test Loss: 0.1611
# - Epoch: 580	- Train Loss: 0.6104	- Test Loss: 0.1621
# - Epoch: 581	- Train Loss: 0.6043	- Test Loss: 0.1610
# - Epoch: 582	- Train Loss: 0.6029	- Test Loss: 0.1613
# - Epoch: 583	- Train Loss: 0.6053	- Test Loss: 0.1660
# - Epoch: 584	- Train Loss: 0.6075	- Test Loss: 0.1606
# - Epoch: 585	- Train Loss: 0.6066	- Test Loss: 0.1650
# - Epoch: 586	- Train Loss: 0.6073	- Test Loss: 0.1638
# - Epoch: 587	- Train Loss: 0.6109	- Test Loss: 0.1638
# - Epoch: 588	- Train Loss: 0.6068	- Test Loss: 0.1637
# - Epoch: 589	- Train Loss: 0.6058	- Test Loss: 0.1619
# - Epoch: 590	- Train Loss: 0.6132	- Test Loss: 0.1618
# - Epoch: 591	- Train Loss: 0.6046	- Test Loss: 0.1657
# - Epoch: 592	- Train Loss: 0.5997	- Test Loss: 0.1645
# - Epoch: 593	- Train Loss: 0.6090	- Test Loss: 0.1601
# - Epoch: 594	- Train Loss: 0.6029	- Test Loss: 0.1630
# - Epoch: 595	- Train Loss: 0.5986	- Test Loss: 0.1617
# - Epoch: 596	- Train Loss: 0.6063	- Test Loss: 0.1624
# - Epoch: 597	- Train Loss: 0.6035	- Test Loss: 0.1623
# - Epoch: 598	- Train Loss: 0.6092	- Test Loss: 0.1643
# - Epoch: 599	- Train Loss: 0.6038	- Test Loss: 0.1623
# - Epoch: 600	- Train Loss: 0.6058	- Test Loss: 0.1606
# Early stopping
# [Tets]
# Accuracy : 0.85
# Micro F1 Score : 0.85
# Macro F1 Score : 0.80

# %%
cm, acc, micf1, macf1 = plot_result(result_df)
# Out:
# Accuracy : 0.85
# Micro F1 Score : 0.85
# Macro F1 Score : 0.80
